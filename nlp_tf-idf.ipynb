# %%
import nltk
import string
import numpy as np

from math import log
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk import corpus

nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /home/alex/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
data = corpus.brown

# %%
stemmer = PorterStemmer()

# %%
stopwords = set(stopwords.words('english'))
stopwords = stopwords.union(string.punctuation)

# %%
stopwords
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '{',
#  '|',
#  '}',
#  '~'}

# %%
fileids = data.fileids()[:30]

# %%
fileids
# Out:
# ['ca01',
#  'ca02',
#  'ca03',
#  'ca04',
#  'ca05',
#  'ca06',
#  'ca07',
#  'ca08',
#  'ca09',
#  'ca10',
#  'ca11',
#  'ca12',
#  'ca13',
#  'ca14',
#  'ca15',
#  'ca16',
#  'ca17',
#  'ca18',
#  'ca19',
#  'ca20',
#  'ca21',
#  'ca22',
#  'ca23',
#  'ca24',
#  'ca25',
#  'ca26',
#  'ca27',
#  'ca28',
#  'ca29',
#  'ca30']

# %%
idf_matrix  = []
dictionary = dict()

# %%
words_count = 0

# %%
documents_count = len(fileids)

# %%
filtered = dict()

# %%
frequencies = dict()
for fileid in fileids:
    frequencies[fileid] = dict()

# %%
frequencies
# Out:
# {'ca01': {},
#  'ca02': {},
#  'ca03': {},
#  'ca04': {},
#  'ca05': {},
#  'ca06': {},
#  'ca07': {},
#  'ca08': {},
#  'ca09': {},
#  'ca10': {},
#  'ca11': {},
#  'ca12': {},
#  'ca13': {},
#  'ca14': {},
#  'ca15': {},
#  'ca16': {},
#  'ca17': {},
#  'ca18': {},
#  'ca19': {},
#  'ca20': {},
#  'ca21': {},
#  'ca22': {},
#  'ca23': {},
#  'ca24': {},
#  'ca25': {},
#  'ca26': {},
#  'ca27': {},
#  'ca28': {},
#  'ca29': {},
#  'ca30': {}}

# %%
for fileid in fileids:
    for word in data.words(fileid):
        # Skipping if it is a stop word
        if word in stopwords:
            continue
        # Before and after filtering
        before_word = word
        if before_word in filtered:
            word = filtered[before_word]
        else:
            # stemming the word
            word = stemmer.stem(word)
            filtered[before_word] = word

        if word in frequencies[fileid]:
            frequencies[fileid][word] += 1
        else:
            frequencies[fileid][word] = 1

        # saving all the words in a dictionary
        if word not in dictionary:
            dictionary[word] = words_count
            words_count += 1

# %%
frequencies
# Out:
# {'ca01': {'the': 28,
#   'fulton': 14,
#   'counti': 17,
#   'grand': 4,
#   'juri': 19,
#   'said': 24,
#   'friday': 4,
#   'investig': 2,
#   "atlanta'": 2,
#   'recent': 1,
#   'primari': 4,
#   'elect': 17,
#   'produc': 1,
#   '``': 34,
#   'evid': 1,
#   "''": 33,
#   'irregular': 3,
#   'took': 2,
#   'place': 4,
#   'term-end': 1,
#   'present': 2,
#   'citi': 9,
#   'execut': 2,
#   'committe': 3,
#   'over-al': 1,
#   'charg': 4,
#   'deserv': 1,
#   'prais': 2,
#   'thank': 1,
#   'atlanta': 5,
#   'manner': 2,
#   'conduct': 1,
#   'september-octob': 1,
#   'term': 3,
#   'superior': 2,
#   'court': 5,
#   'judg': 1,
#   'durwood': 1,
#   'pye': 1,
#   'report': 2,
#   'possibl': 1,
#   'hard-fought': 1,
#   'mayor-nomin': 1,
#   'ivan': 2,
#   'allen': 2,
#   'jr.': 3,
#   'onli': 1,
#   'rel': 1,
#   'hand': 1,
#   'receiv': 6,
#   'consid': 1,
#   'widespread': 1,
#   'interest': 2,
#   'number': 3,
#   'voter': 4,
#   'size': 1,
#   'find': 1,
#   'mani': 2,
#   "georgia'": 4,
#   'registr': 1,
#   'law': 5,
#   'outmod': 1,
#   'inadequ': 1,
#   'often': 1,
#   'ambigu': 1,
#   'It': 6,
#   'recommend': 5,
#   'legisl': 7,
#   'act': 2,
#   'studi': 2,
#   'revis': 1,
#   'end': 1,
#   'modern': 1,
#   'improv': 1,
#   'comment': 2,
#   'topic': 1,
#   'among': 1,
#   'purchas': 2,
#   'depart': 11,
#   'well': 1,
#   'oper': 4,
#   'follow': 2,
#   'gener': 3,
#   'accept': 1,
#   'practic': 3,
#   'inur': 1,
#   'best': 1,
#   'govern': 1,
#   'merger': 1,
#   'propos': 2,
#   'howev': 3,
#   'believ': 1,
#   'two': 3,
#   'offic': 3,
#   'combin': 1,
#   'achiev': 1,
#   'greater': 1,
#   'effici': 1,
#   'reduc': 1,
#   'cost': 2,
#   'administr': 3,
#   'lack': 1,
#   'experienc': 1,
#   'cleric': 1,
#   'personnel': 2,
#   'result': 1,
#   'polici': 1,
#   'urg': 2,
#   'take': 3,
#   'step': 1,
#   'remedi': 1,
#   'problem': 1,
#   'implement': 2,
#   'automobil': 1,
#   'titl': 1,
#   'also': 3,
#   'outgo': 1,
#   'next': 1,
#   'legislatur': 4,
#   'provid': 3,
#   'enabl': 2,
#   'fund': 10,
#   're-set': 1,
#   'effect': 3,
#   'date': 1,
#   'orderli': 2,
#   'may': 1,
#   'swipe': 1,
#   'state': 12,
#   'welfar': 4,
#   "department'": 1,
#   'handl': 1,
#   'feder': 4,
#   'grant': 1,
#   'child': 1,
#   'servic': 1,
#   'foster': 1,
#   'home': 3,
#   'thi': 2,
#   'one': 5,
#   'major': 1,
#   'item': 2,
#   'assist': 2,
#   'program': 2,
#   'seen': 1,
#   'fit': 1,
#   'distribut': 2,
#   'except': 2,
#   'none': 2,
#   'money': 2,
#   'juror': 2,
#   'realiz': 1,
#   'proportion': 1,
#   'might': 1,
#   'disabl': 1,
#   'less': 1,
#   'popul': 1,
#   'nevertheless': 1,
#   'feel': 1,
#   'futur': 2,
#   'portion': 2,
#   'avail': 1,
#   'failur': 1,
#   'continu': 1,
#   'disproportion': 1,
#   'burden': 1,
#   'taxpay': 1,
#   "ordinary'": 1,
#   'fire': 1,
#   'appoint': 2,
#   'apprais': 1,
#   'guardian': 1,
#   'award': 1,
#   'fee': 1,
#   'compens': 1,
#   'ward': 2,
#   'protect': 2,
#   'found': 1,
#   'incorpor': 1,
#   'procedur': 1,
#   'previou': 1,
#   'bar': 1,
#   'associ': 1,
#   'interim': 1,
#   'citizen': 2,
#   'these': 1,
#   'action': 4,
#   'serv': 1,
#   'fact': 1,
#   "court'": 1,
#   'undu': 1,
#   'servant': 1,
#   'unmeritori': 1,
#   'critic': 1,
#   'regard': 1,
#   'new': 6,
#   'multi-million-dollar': 1,
#   'airport': 2,
#   'manag': 1,
#   'jan.': 2,
#   '1': 4,
#   'elimin': 1,
#   'polit': 2,
#   'influenc': 1,
#   'elabor': 1,
#   'ad': 3,
#   'period': 1,
#   'surveil': 1,
#   'price': 2,
#   'concessionair': 1,
#   'purpos': 1,
#   'keep': 1,
#   'reason': 1,
#   'ask': 5,
#   'jail': 3,
#   'deputi': 2,
#   'On': 1,
#   'matter': 1,
#   'four': 2,
#   'addit': 2,
#   'employ': 3,
#   'doctor': 1,
#   'medic': 1,
#   'intern': 1,
#   'extern': 1,
#   'night': 4,
#   'weekend': 1,
#   'duti': 1,
#   '2': 3,
#   'work': 6,
#   'offici': 2,
#   'pass': 3,
#   'permit': 2,
#   'establish': 1,
#   'fair': 1,
#   'equit': 1,
#   'pension': 1,
#   'plan': 3,
#   'polic': 1,
#   'tax': 2,
#   "commissioner'": 1,
#   'bellwood': 1,
#   'alpharetta': 1,
#   'prison': 1,
#   'farm': 1,
#   'gradi': 1,
#   'hospit': 1,
#   'health': 1,
#   'mayor': 4,
#   'william': 7,
#   'B.': 2,
#   'hartsfield': 5,
#   'file': 1,
#   'suit': 2,
#   'divorc': 1,
#   'wife': 2,
#   'pearl': 1,
#   'hi': 2,
#   'petit': 6,
#   'mental': 1,
#   'cruelti': 1,
#   'coupl': 2,
#   'marri': 1,
#   'aug.': 1,
#   '1913': 1,
#   'they': 1,
#   'son': 1,
#   'berri': 1,
#   'daughter': 1,
#   'mrs.': 1,
#   'J.': 1,
#   'M.': 1,
#   'cheshir': 1,
#   'griffin': 2,
#   'attorney': 3,
#   'amic': 1,
#   'properti': 1,
#   'settlement': 1,
#   'agre': 1,
#   'upon': 1,
#   'list': 3,
#   "mayor'": 3,
#   'occup': 1,
#   'age': 2,
#   '71': 1,
#   "wife'": 1,
#   '74': 1,
#   'birth': 1,
#   'opelika': 1,
#   'ala.': 1,
#   'live': 1,
#   'togeth': 1,
#   'man': 1,
#   'year': 3,
#   '637': 1,
#   'E.': 1,
#   'pelham': 5,
#   'rd.': 1,
#   'Aj': 1,
#   'henri': 1,
#   'L.': 1,
#   'bowden': 1,
#   'brief': 1,
#   'interlud': 1,
#   'sinc': 1,
#   '1937': 1,
#   'career': 1,
#   'goe': 1,
#   'back': 2,
#   'council': 1,
#   '1923': 1,
#   'expir': 1,
#   'He': 2,
#   'succeed': 2,
#   'becam': 1,
#   'candid': 6,
#   'sept.': 2,
#   '13': 1,
#   'announc': 1,
#   'would': 9,
#   'run': 1,
#   'reelect': 1,
#   'georgia': 4,
#   'republican': 5,
#   'get': 1,
#   'strong': 1,
#   'encourag': 1,
#   'enter': 3,
#   '1962': 1,
#   "governor'": 1,
#   'race': 4,
#   'top': 1,
#   'wednesday': 1,
#   'robert': 1,
#   'snodgrass': 1,
#   'gop': 1,
#   'chairman': 3,
#   'meet': 2,
#   'held': 2,
#   'tuesday': 2,
#   'blue': 2,
#   'ridg': 2,
#   'brought': 1,
#   'enthusiast': 1,
#   'respons': 1,
#   'audienc': 2,
#   'parti': 2,
#   'jame': 1,
#   'W.': 1,
#   'dorsey': 1,
#   'enthusiasm': 1,
#   'pick': 1,
#   'ralli': 1,
#   '8': 1,
#   'savannah': 1,
#   'newli': 1,
#   'texa': 1,
#   'sen.': 1,
#   'john': 1,
#   'tower': 1,
#   'featur': 1,
#   'speaker': 1,
#   'In': 1,
#   'warn': 2,
#   'governor': 2,
#   'forc': 1,
#   'vote': 9,
#   'precinct': 1,
#   'obtain': 1,
#   'signatur': 1,
#   'regist': 1,
#   'despit': 1,
#   'unanim': 1,
#   'accord': 1,
#   'attend': 1,
#   'when': 2,
#   'crowd': 1,
#   'whether': 3,
#   'want': 1,
#   'wait': 1,
#   'make': 4,
#   '--': 4,
#   'dissent': 1,
#   'largest': 1,
#   'hurdl': 1,
#   'face': 1,
#   'say': 2,
#   'first': 4,
#   'altern': 1,
#   'cours': 1,
#   'must': 3,
#   'taken': 1,
#   'five': 1,
#   'per': 2,
#   'cent': 1,
#   'sign': 1,
#   'request': 1,
#   'allow': 3,
#   'name': 1,
#   'ballot': 1,
#   'hold': 1,
#   'unit': 1,
#   'system': 2,
#   'oppos': 2,
#   'platform': 1,
#   'sam': 1,
#   'caldwel': 2,
#   'highway': 8,
#   'public': 2,
#   'relat': 1,
#   'director': 1,
#   'resign': 3,
#   'lt.': 1,
#   'gov.': 3,
#   'garland': 1,
#   "byrd'": 1,
#   'campaign': 5,
#   "caldwell'": 1,
#   'expect': 4,
#   'time': 2,
#   'rob': 1,
#   'ledford': 1,
#   'gainesvil': 1,
#   'three': 1,
#   'gubernatori': 1,
#   'start': 1,
#   'becom': 1,
#   'coordin': 1,
#   'byrd': 1,
#   'wind': 1,
#   '1961': 1,
#   'session': 3,
#   'monday': 5,
#   'head': 1,
#   'bond': 9,
#   'approv': 3,
#   'shortli': 1,
#   'befor': 1,
#   'adjourn': 2,
#   'afternoon': 1,
#   'senat': 2,
#   'allot': 1,
#   'rural': 6,
#   'urban': 1,
#   'area': 1,
#   'determin': 1,
#   'adjust': 1,
#   'made': 2,
#   'vandiv': 4,
#   'tradit': 1,
#   'visit': 1,
#   'chamber': 1,
#   'toward': 1,
#   'like': 3,
#   'mention': 1,
#   '$100': 1,
#   'million': 5,
#   'issu': 6,
#   'earlier': 1,
#   'prioriti': 2,
#   'construct': 2,
#   'meanwhil': 1,
#   'learn': 1,
#   'near': 1,
#   'readi': 1,
#   '$30': 1,
#   'worth': 3,
#   'reconstruct': 1,
#   'go': 1,
#   'friendli': 1,
#   'test': 2,
#   'valid': 1,
#   'sale': 1,
#   'begin': 1,
#   'contract': 1,
#   'let': 1,
#   'repair': 1,
#   'heavili': 1,
#   'travel': 1,
#   'A': 4,
#   'sourc': 2,
#   '$3': 1,
#   '$4': 1,
#   'road': 5,
#   'author': 3,
#   'revolv': 2,
#   'appar': 2,
#   'intend': 1,
#   'everi': 1,
#   'old': 1,
#   'paid': 1,
#   'open': 1,
#   '1958': 1,
#   'battl': 1,
#   'issuanc': 1,
#   '$50': 1,
#   'marvin': 1,
#   'told': 1,
#   'constitut': 2,
#   'consult': 1,
#   'yet': 1,
#   'schley': 1,
#   'rep.': 2,
#   'D.': 1,
#   'offer': 3,
#   'resolut': 9,
#   'hous': 5,
#   'rescind': 2,
#   "body'": 1,
#   '$10': 1,
#   'day': 2,
#   'increas': 4,
#   'expens': 1,
#   'sunday': 2,
#   'research': 1,
#   'done': 1,
#   'quicki': 1,
#   'repeal': 1,
#   'outright': 1,
#   'notic': 1,
#   'given': 1,
#   'reconsider': 1,
#   'sought': 1,
#   'while': 1,
#   'emphas': 1,
#   'technic': 1,
#   'detail': 1,
#   'fulli': 1,
#   'seek': 1,
#   'set': 1,
#   'asid': 1,
#   'privileg': 2,
#   '87-31': 1,
#   'similar': 1,
#   '29-5': 1,
#   'As': 1,
#   'word': 1,
#   'point': 1,
#   'last': 1,
#   'novemb': 1,
#   'reject': 1,
#   'amend': 1,
#   'pay': 2,
#   'rais': 2,
#   'veteran': 2,
#   'jackson': 1,
#   'aid': 1,
#   'educ': 3,
#   'someth': 1,
#   'consist': 1,
#   'past': 1,
#   'mac': 1,
#   'barber': 3,
#   'commerc': 1,
#   'endors': 1,
#   'support': 1,
#   'expend': 1,
#   '13th': 1,
#   'member': 1,
#   'congression': 1,
#   'deleg': 1,
#   'washington': 1,
#   'see': 1,
#   'but': 1,
#   'congressmen': 1,
#   'specif': 1,
#   'toss': 1,
#   'hopper': 1,
#   'formal': 1,
#   'read': 1,
#   'event': 1,
#   'congress': 1,
#   'board': 2,
#   'direct': 1,
#   'give': 1,
#   'teacher': 2,
#   'colquitt': 2,
#   'after': 1,
#   'long': 1,
#   'hot': 1,
#   'controversi': 2,
#   'miller': 2,
#   'school': 5,
#   'superintend': 3,
#   'policeman': 2,
#   'put': 1,
#   'coolest': 2,
#   'I': 3,
#   'ever': 2,
#   'saw': 2,
#   'harri': 1,
#   'davi': 3,
#   'agricultur': 1,
#   'defeat': 1,
#   'felix': 2,
#   'bush': 3,
#   'princip': 1,
#   'democrat': 1,
#   '1,119': 1,
#   "saturday'": 1,
#   'got': 2,
#   '402': 1,
#   'ordinari': 3,
#   'carey': 1,
#   'arm': 1,
#   'pistol': 1,
#   'stood': 1,
#   'poll': 3,
#   'insur': 1,
#   'order': 1,
#   'calmest': 1,
#   'tom': 1,
#   'be': 1,
#   'church': 1,
#   'smell': 1,
#   'drop': 1,
#   'liquor': 1,
#   'bit': 2,
#   'troubl': 2,
#   'lead': 1,
#   'quiet': 1,
#   'mark': 1,
#   'anonym': 3,
#   'midnight': 1,
#   'phone': 1,
#   'call': 3,
#   'veil': 1,
#   'threat': 1,
#   'violenc': 1,
#   'former': 1,
#   'georg': 1,
#   'P.': 1,
#   'callan': 1,
#   'shot': 1,
#   'death': 1,
#   'march': 1,
#   '18': 1,
#   'post': 1,
#   'disput': 1,
#   'dure': 1,
#   'reportedli': 1,
#   'telephon': 1,
#   'subject': 1,
#   'soon': 1,
#   'schedul': 1,
#   'local': 1,
#   'fear': 1,
#   'carri': 1,
#   'gun': 1,
#   'promis': 2,
#   'sheriff': 2,
#   'tabb': 1,
#   'good': 1,
#   'everyth': 1,
#   'went': 1,
#   'real': 1,
#   'smooth': 1,
#   'there': 1},
#  'ca02': {'austin': 7,
#   'texa': 21,
#   '--': 7,
#   'committe': 13,
#   'approv': 4,
#   'gov.': 1,
#   'price': 1,
#   "daniel'": 1,
#   '``': 19,
#   'abandon': 1,
#   'properti': 4,
#   "''": 19,
#   'act': 3,
#   'seem': 1,
#   'certain': 1,
#   'thursday': 5,
#   'despit': 1,
#   'adam': 1,
#   'protest': 1,
#   'banker': 4,
#   'daniel': 4,
#   'person': 5,
#   'led': 1,
#   'fight': 1,
#   'measur': 2,
#   'water': 6,
#   'consider': 1,
#   'sinc': 4,
#   'reject': 2,
#   'two': 4,
#   'previou': 1,
#   'legislatur': 3,
#   'public': 5,
#   'hear': 4,
#   'hous': 7,
#   'revenu': 1,
#   'taxat': 1,
#   'under': 2,
#   'rule': 1,
#   'went': 1,
#   'automat': 1,
#   'subcommitte': 1,
#   'one': 7,
#   'week': 1,
#   'but': 2,
#   'question': 2,
#   'member': 2,
#   'taunt': 1,
#   'appear': 1,
#   'wit': 1,
#   'left': 1,
#   'littl': 2,
#   'doubt': 1,
#   'recommend': 5,
#   'passag': 1,
#   'term': 2,
#   'extrem': 1,
#   'conserv': 1,
#   'estim': 2,
#   'would': 26,
#   'produc': 1,
#   '17': 1,
#   'million': 4,
#   'dollar': 4,
#   'help': 3,
#   'eras': 1,
#   'anticip': 1,
#   'deficit': 1,
#   '63': 1,
#   'end': 2,
#   'current': 1,
#   'fiscal': 1,
#   'year': 5,
#   'next': 1,
#   'aug.': 1,
#   '31': 1,
#   'He': 4,
#   'told': 2,
#   'mere': 1,
#   'provid': 3,
#   'mean': 2,
#   'enforc': 2,
#   'escheat': 2,
#   'law': 3,
#   'book': 1,
#   'republ': 1,
#   'It': 3,
#   'permit': 3,
#   'state': 13,
#   'take': 3,
#   'bank': 6,
#   'account': 1,
#   'stock': 2,
#   'miss': 1,
#   'seven': 1,
#   'the': 18,
#   'bill': 22,
#   'said': 14,
#   'draft': 1,
#   'forc': 3,
#   'insur': 2,
#   'firm': 2,
#   'pipelin': 2,
#   'compani': 3,
#   'corpor': 1,
#   'report': 7,
#   'treasur': 1,
#   'cannot': 1,
#   'almost': 1,
#   'imposs': 1,
#   'locat': 1,
#   'declar': 1,
#   'dewey': 1,
#   'lawrenc': 1,
#   'tyler': 1,
#   'lawyer': 1,
#   'repres': 4,
#   'associ': 2,
#   'sound': 1,
#   'opposit': 1,
#   'keynot': 1,
#   'violat': 2,
#   'contractu': 1,
#   'oblig': 1,
#   'depositor': 1,
#   'undermin': 1,
#   'confid': 2,
#   'custom': 1,
#   'If': 1,
#   'destroy': 1,
#   'someth': 1,
#   'economi': 1,
#   'you': 1,
#   'circul': 1,
#   'mani': 1,
#   'rep.': 6,
#   'charl': 2,
#   'E.': 2,
#   'hugh': 1,
#   'sherman': 2,
#   'sponsor': 3,
#   'failur': 1,
#   'enact': 1,
#   'amount': 1,
#   'make': 3,
#   'gift': 2,
#   "taxpayers'": 1,
#   'pocket': 1,
#   'hi': 1,
#   'content': 1,
#   'deni': 1,
#   'sever': 1,
#   'includ': 2,
#   'scott': 2,
#   'hudson': 1,
#   'gaynor': 1,
#   'B.': 2,
#   'jone': 2,
#   'houston': 3,
#   'J.': 3,
#   'bradi': 1,
#   'harlingen': 1,
#   'howard': 1,
#   'cox': 2,
#   'argu': 2,
#   'probabl': 1,
#   'unconstitut': 1,
#   'impair': 1,
#   'contract': 1,
#   'also': 4,
#   'complain': 1,
#   'enough': 2,
#   'notic': 1,
#   'given': 2,
#   'introduc': 1,
#   'last': 1,
#   'monday': 1,
#   'senat': 8,
#   'unanim': 1,
#   'sen.': 7,
#   'georg': 2,
#   'parkhous': 5,
#   'dalla': 13,
#   'author': 5,
#   'establish': 3,
#   'day': 5,
#   'school': 18,
#   'deaf': 6,
#   'four': 1,
#   'largest': 1,
#   'counti': 8,
#   'design': 2,
#   'special': 3,
#   'student': 1,
#   'scholast': 2,
#   'age': 2,
#   'reduc': 4,
#   'cost': 2,
#   'there': 1,
#   'debat': 2,
#   'pass': 7,
#   'educ': 6,
#   'agenc': 1,
#   'county-wid': 1,
#   '300,000': 1,
#   'popul': 2,
#   'requir': 6,
#   'children': 3,
#   '6': 1,
#   '13': 2,
#   'attend': 3,
#   'older': 1,
#   'residenti': 1,
#   'oper': 1,
#   'budget': 1,
#   'five': 2,
#   'harri': 1,
#   'bexar': 1,
#   'tarrant': 1,
#   'El': 2,
#   'paso': 2,
#   '$451,500': 1,
#   'save': 2,
#   '$157,460': 1,
#   'yearli': 1,
#   'first': 1,
#   "year'": 2,
#   'capit': 1,
#   'outlay': 1,
#   '$88,000': 1,
#   'absorb': 1,
#   'tea': 1,
#   '182': 1,
#   'come': 1,
#   'live': 2,
#   'may': 1,
#   'get': 3,
#   'hors': 2,
#   'race': 2,
#   'parimutuel': 1,
#   'soon': 2,
#   'reps.': 1,
#   'V.': 1,
#   'red': 1,
#   'berri': 2,
#   'joe': 2,
#   'ratcliff': 3,
#   'while': 1,
#   'detail': 1,
#   'still': 1,
#   'work': 2,
#   'expect': 2,
#   'tell': 1,
#   'home': 1,
#   'folk': 1,
#   'think': 1,
#   "berry'": 1,
#   'propos': 7,
#   'constitut': 2,
#   'amend': 3,
#   "we'r": 1,
#   'pro': 1,
#   'letter': 1,
#   'con': 1,
#   'bet': 2,
#   'I': 2,
#   'believ': 1,
#   'peopl': 3,
#   'better': 2,
#   'inform': 2,
#   'oppos': 1,
#   "i'm": 1,
#   'will': 1,
#   'stake': 1,
#   'polit': 1,
#   'career': 2,
#   'ex-gambl': 1,
#   'san': 2,
#   'antonio': 1,
#   'got': 1,
#   'elect': 2,
#   'advocaci': 1,
#   'poni': 1,
#   'A': 5,
#   'heard': 1,
#   'local': 3,
#   'option': 1,
#   'give': 3,
#   'favor': 1,
#   'although': 1,
#   'resolut': 1,
#   'face': 1,
#   'hard': 1,
#   'sled': 1,
#   'later': 2,
#   'final': 3,
#   'sent': 1,
#   'extend': 1,
#   'health': 1,
#   "department'": 1,
#   'plan': 3,
#   'assist': 1,
#   'citi': 5,
#   'quickli': 1,
#   'whip': 1,
#   'meager': 1,
#   'fare': 1,
#   'three': 1,
#   'calendar': 1,
#   'valid': 1,
#   'district': 6,
#   'anoth': 1,
#   'enlarg': 1,
#   'beaumont': 1,
#   'navig': 1,
#   'third': 1,
#   'enabl': 1,
#   'creation': 1,
#   'lamar': 1,
#   'hospit': 2,
#   'previous': 1,
#   'adopt': 1,
#   'without': 1,
#   'dissent': 1,
#   'A.': 2,
#   'R.': 2,
#   'schwartz': 1,
#   'galveston': 1,
#   'futur': 2,
#   'mental': 1,
#   'retard': 1,
#   'gulf': 1,
#   'coast': 1,
#   'money': 2,
#   'construct': 1,
#   'sought': 1,
#   'meantim': 1,
#   'board': 3,
#   'accept': 1,
#   'donat': 1,
#   'site': 2,
#   'tax': 4,
#   'revis': 1,
#   'loui': 1,
#   'crump': 1,
#   'saba': 1,
#   'aid': 2,
#   '17,000': 1,
#   'retail': 2,
#   'pay': 4,
#   'group': 1,
#   'miscellan': 1,
#   'excis': 1,
#   'elimin': 2,
#   'return': 1,
#   'notar': 1,
#   'instead': 1,
#   'sign': 1,
#   'certif': 2,
#   'correct': 1,
#   'carri': 1,
#   'penalti': 1,
#   'prison': 1,
#   'plu': 1,
#   '$1,000': 1,
#   'fine': 1,
#   'seri': 1,
#   'research': 2,
#   'leagu': 1,
#   'M.': 1,
#   'aikin': 1,
#   'jr.': 1,
#   'pari': 3,
#   'reliev': 1,
#   'real': 1,
#   'estat': 1,
#   'broker': 2,
#   'annual': 2,
#   'licens': 2,
#   'fee': 1,
#   '$12': 1,
#   'occup': 1,
#   'bond': 3,
#   'natur': 1,
#   'ga': 2,
#   'util': 1,
#   'right': 1,
#   'emin': 1,
#   'domain': 1,
#   'frank': 1,
#   'owen': 1,
#   '3': 1,
#   'acquir': 1,
#   'underground': 1,
#   'storag': 1,
#   'reservoir': 1,
#   'marshal': 1,
#   'formbi': 1,
#   'plainview': 1,
#   'former': 1,
#   'chairman': 3,
#   'highway': 1,
#   'commiss': 1,
#   'suggest': 1,
#   'fill': 1,
#   'appoint': 1,
#   'vacanc': 1,
#   'congress': 1,
#   'need': 3,
#   'costli': 1,
#   "formby'": 1,
#   'appointe': 1,
#   'select': 1,
#   'compos': 1,
#   'governor': 2,
#   'lieuten': 1,
#   'speaker': 1,
#   'attorney': 1,
#   'gener': 3,
#   'chief': 1,
#   'justic': 1,
#   'suprem': 1,
#   'court': 1,
#   'decid': 1,
#   'poll': 2,
#   'kind': 1,
#   'texan': 2,
#   'prefer': 1,
#   'An': 1,
#   'advers': 1,
#   'vote': 4,
#   '81': 1,
#   '65': 1,
#   'kept': 1,
#   'affair': 1,
#   'order': 1,
#   'referendum': 1,
#   'april': 2,
#   '4': 3,
#   'ballot': 3,
#   'u.s.': 2,
#   'wesley': 1,
#   'robert': 3,
#   'seminol': 1,
#   'idea': 1,
#   'delay': 1,
#   'kill': 1,
#   'west': 1,
#   'gotten': 1,
#   'hollowel': 1,
#   'set': 1,
#   'feb.': 1,
#   '22': 1,
#   'receiv': 2,
#   'legisl': 4,
#   'two-third': 1,
#   'major': 1,
#   'march': 1,
#   '1': 1,
#   'print': 1,
#   'oppon': 1,
#   'voter': 1,
#   'intellig': 1,
#   'choic': 1,
#   'all': 1,
#   'except': 1,
#   'absent': 1,
#   'paradis': 2,
#   'lost': 1,
#   'alleg': 1,
#   "texas'": 1,
#   'big': 2,
#   'jame': 1,
#   'cotten': 4,
#   'weatherford': 2,
#   'insist': 1,
#   'develop': 1,
#   'effort': 2,
#   'like': 3,
#   'fort': 3,
#   'worth': 2,
#   'cover': 1,
#   'place': 2,
#   'wise': 1,
#   'hamlet': 1,
#   '250': 1,
#   'when': 1,
#   'shout': 1,
#   '114': 1,
#   'send': 1,
#   'similar': 1,
#   'most': 1,
#   'fire': 1,
#   'direct': 1,
#   'increas': 1,
#   '$5,000,000': 1,
#   '$15,000,000': 1,
#   'maximum': 1,
#   'loan': 1,
#   'could': 2,
#   'project': 2,
#   'constru': 1,
#   'veil': 1,
#   'larg': 1,
#   'felt': 1,
#   'spent': 2,
#   'rural': 1,
#   'statement': 1,
#   'program': 4,
#   'less': 1,
#   'benefit': 1,
#   'pend': 1,
#   'sway': 1,
#   "cotten'": 1,
#   'attack': 1,
#   "bill'": 1,
#   'defend': 1,
#   'mostli': 1,
#   'small-town': 1,
#   'W.': 1,
#   'buchanan': 1,
#   'duma': 1,
#   'eligio': 1,
#   'kika': 1,
#   'De': 1,
#   'La': 1,
#   'garza': 1,
#   'mission': 1,
#   'sam': 1,
#   'F.': 1,
#   'collin': 1,
#   'newton': 1,
#   'chapman': 2,
#   'sulphur': 1,
#   'spring': 1,
#   'thi': 2,
#   'poor': 1,
#   "boy'": 1,
#   'peanut': 1,
#   'teacher': 5,
#   'serv': 3,
#   'time': 1,
#   'learn': 1,
#   'method': 2,
#   'henri': 1,
#   'C.': 2,
#   'grover': 4,
#   'teach': 5,
#   'histori': 1,
#   '24': 2,
#   '12': 1,
#   'semest': 3,
#   'hour': 3,
#   'so-cal': 1,
#   'cours': 3,
#   'obtain': 1,
#   'junior': 2,
#   'senior': 1,
#   'high': 4,
#   'normal': 1,
#   'colleg': 9,
#   '30': 1,
#   'junior-senior': 1,
#   'least': 1,
#   'credit': 1,
#   'subject': 2,
#   'remaind': 1,
#   '4-year': 1,
#   "master'": 1,
#   'degre': 4,
#   'physic': 1,
#   'chemistri': 1,
#   'math': 1,
#   'english': 1,
#   'yet': 1,
#   'taken': 1,
#   'fifty-thre': 1,
#   '150': 1,
#   'immedi': 1,
#   'join': 1,
#   'co-sign': 1,
#   'sp.': 2,
#   'regent': 1,
#   'name': 1,
#   'dr.': 7,
#   'clarenc': 1,
#   'clark': 6,
#   'hay': 2,
#   'kan.': 2,
#   "school'": 1,
#   'new': 2,
#   'presid': 2,
#   'succeed': 1,
#   'mclemor': 1,
#   'retir': 1,
#   'close': 1,
#   'present': 1,
#   'hold': 1,
#   'earn': 1,
#   'doctor': 1,
#   'univers': 2,
#   'oklahoma': 3,
#   'master': 1,
#   'scienc': 2,
#   'bachelor': 1,
#   'southwestern': 1,
#   'okla.': 1,
#   'In': 1,
#   'addit': 1,
#   'studi': 2,
#   'rhode': 1,
#   'island': 1,
#   'massachusett': 1,
#   'institut': 1,
#   'technolog': 1,
#   'dure': 1,
#   'captain': 1,
#   'basketbal': 1,
#   'team': 1,
#   'footbal': 1,
#   'letterman': 1,
#   'princip': 3,
#   'athlet': 1,
#   'director': 1,
#   'raymondvil': 1,
#   'instructor': 1,
#   'professor': 1,
#   'border': 1,
#   'patrolman': 1,
#   'signal': 1,
#   'corp': 1,
#   'armi': 1,
#   'denton': 2,
#   'independ': 1,
#   're-elect': 1,
#   '1961-62': 1,
#   'session': 1,
#   'upon': 2,
#   'supt.': 1,
#   'chester': 1,
#   'O.': 1,
#   'strickland': 1,
#   'feder': 1,
#   'racial': 2,
#   'discrimin': 3,
#   'employ': 3,
#   'call': 3,
#   'yesterday': 1,
#   'blue': 1,
#   'ribbon': 1,
#   'citizen': 1,
#   'depend': 4,
#   'culmin': 1,
#   'long': 2,
#   'adc': 8,
#   'cook': 1,
#   'york': 1,
#   'welfar': 1,
#   'consult': 1,
#   'list': 1,
#   '10': 1,
#   'rang': 1,
#   'soar': 1,
#   'case': 2,
#   'load': 1,
#   'seriou': 1,
#   'caus': 3,
#   'famili': 3,
#   'breakdown': 1,
#   'desert': 1,
#   'must': 2,
#   'solv': 2,
#   'problem': 3,
#   'monthli': 1,
#   '100,000': 1,
#   'recipi': 1,
#   '4.4': 1,
#   'virgil': 1,
#   'martin': 3,
#   'carson': 1,
#   'piri': 1,
#   'co.': 1,
#   'We': 1,
#   'subsist': 1,
#   'volum': 1,
#   'decreas': 1,
#   'commun': 1,
#   'abl': 1,
#   'deal': 1,
#   'effect': 1,
#   'rel': 2,
#   'limit': 1,
#   'skill': 1,
#   'color': 1,
#   'these': 1,
#   'underli': 1,
#   'breakup': 1,
#   'lead': 1,
#   'extens': 2,
#   'other': 1,
#   'made': 1,
#   'parent': 1,
#   'preserv': 1,
#   'uniti': 1,
#   'possibl': 1,
#   'prevent': 1,
#   'illegitimaci': 1},
#  'ca03': {'sever': 2,
#   'defend': 5,
#   'summerdal': 1,
#   'polic': 1,
#   'burglari': 1,
#   'trial': 6,
#   'made': 7,
#   'statement': 6,
#   'indic': 2,
#   'guilt': 2,
#   'time': 2,
#   'arrest': 1,
#   'judg': 9,
#   'jame': 1,
#   'B.': 1,
#   'parson': 3,
#   'told': 3,
#   'crimin': 4,
#   'court': 9,
#   'yesterday': 2,
#   'the': 22,
#   'disclosur': 2,
#   'charl': 2,
#   'bellow': 5,
#   'chief': 3,
#   'defens': 1,
#   'counsel': 1,
#   'startl': 1,
#   'observ': 1,
#   'view': 1,
#   'prelud': 1,
#   'quarrel': 1,
#   'six': 1,
#   'attorney': 2,
#   'repres': 1,
#   'eight': 3,
#   'former': 1,
#   'policemen': 1,
#   'ask': 7,
#   'grant': 13,
#   'client': 2,
#   'alan': 1,
#   'clement': 1,
#   '30': 2,
#   'separ': 1,
#   'request': 2,
#   'all-woman': 1,
#   'juri': 5,
#   'courtroom': 1,
#   'fear': 1,
#   'prejudici': 2,
#   'aspect': 1,
#   '``': 30,
#   'may': 2,
#   'highli': 1,
#   "''": 29,
#   'some': 1,
#   'strongli': 1,
#   'knew': 1,
#   'receiv': 3,
#   'stolen': 1,
#   'properti': 1,
#   'It': 4,
#   'imposs': 1,
#   'get': 1,
#   'fair': 2,
#   'involv': 7,
#   'other': 2,
#   'lean': 1,
#   'bench': 1,
#   'inquir': 1,
#   'you': 1,
#   'mean': 3,
#   'admit': 2,
#   'ye': 1,
#   'honor': 1,
#   'repli': 2,
#   'what': 1,
#   'amount': 3,
#   'true': 1,
#   'free-for-al': 1,
#   'fight': 2,
#   'case': 14,
#   'there': 1,
#   'conflict': 1,
#   'among': 1,
#   'washington': 5,
#   'juli': 1,
#   '24': 2,
#   '--': 9,
#   'presid': 16,
#   'kennedi': 6,
#   'today': 2,
#   'push': 1,
#   'asid': 1,
#   'white': 5,
#   'hous': 10,
#   'busi': 1,
#   'devot': 1,
#   'attent': 1,
#   'work': 2,
#   'berlin': 2,
#   'crisi': 2,
#   'address': 4,
#   'deliv': 1,
#   'tomorrow': 1,
#   'night': 1,
#   'american': 3,
#   'peopl': 3,
#   'nationwid': 1,
#   'televis': 1,
#   'radio': 1,
#   'spent': 1,
#   'much': 3,
#   'week-end': 1,
#   'summer': 1,
#   'home': 9,
#   'cape': 1,
#   'cod': 1,
#   'write': 1,
#   'first': 7,
#   'draft': 2,
#   'portion': 1,
#   'help': 2,
#   'aid': 1,
#   'talk': 1,
#   'telephon': 1,
#   'shortli': 1,
#   'execut': 1,
#   'return': 1,
#   'midmorn': 1,
#   'hyanni': 1,
#   'port': 1,
#   'mass.': 1,
#   'spokesman': 1,
#   'said': 17,
#   'text': 1,
#   'still': 2,
#   'quit': 1,
#   'way': 1,
#   'go': 6,
#   'toward': 1,
#   'complet': 1,
#   'decis': 2,
#   'elabor': 1,
#   'pierr': 1,
#   'saling': 2,
#   'press': 1,
#   'secretari': 1,
#   'I': 1,
#   'would': 20,
#   'say': 2,
#   'got': 1,
#   'thru': 1,
#   'advis': 3,
#   'member': 1,
#   'staff': 1,
#   'composit': 1,
#   'word': 1,
#   'rather': 1,
#   'last': 9,
#   'minut': 1,
#   'administr': 2,
#   'plan': 15,
#   'meet': 4,
#   'latest': 1,
#   'precipit': 1,
#   "russia'": 1,
#   'demand': 3,
#   'propos': 8,
#   'citi': 2,
#   '10': 6,
#   'investig': 2,
#   'nov.': 1,
#   '8': 1,
#   'elect': 3,
#   'dismiss': 2,
#   'act': 3,
#   'john': 1,
#   'M.': 1,
#   'karn': 7,
#   'charg': 2,
#   'prosecut': 1,
#   'obtain': 2,
#   'evid': 2,
#   'unfair': 1,
#   'fundament': 1,
#   'illeg': 1,
#   'matter': 1,
#   'even': 1,
#   'greater': 1,
#   'signific': 1,
#   'innoc': 1,
#   '50': 2,
#   'person': 7,
#   'He': 7,
#   'violat': 1,
#   'legal': 1,
#   'right': 1,
#   'citizen': 1,
#   "karns'": 1,
#   'rule': 5,
#   'pertain': 1,
#   'In': 5,
#   'two': 2,
#   'state': 4,
#   'unabl': 1,
#   'make': 1,
#   'contempt': 2,
#   'proceed': 1,
#   'origin': 1,
#   'brought': 1,
#   '677': 1,
#   '133': 1,
#   'precinct': 8,
#   'morri': 1,
#   'J.': 1,
#   'wexler': 6,
#   'special': 2,
#   'prosecutor': 1,
#   'issu': 2,
#   'subpoena': 1,
#   'earlier': 1,
#   'hear': 2,
#   'grand': 3,
#   'subpena': 2,
#   '200': 1,
#   'question': 2,
#   'individu': 1,
#   'build': 4,
#   'take': 2,
#   'mayer': 1,
#   'goldberg': 1,
#   '58th': 2,
#   '23d': 4,
#   'ward': 7,
#   'argu': 1,
#   'procedur': 1,
#   'constitut': 3,
#   'intimid': 1,
#   'deni': 2,
#   'repeatedli': 1,
#   'coercion': 1,
#   'use': 3,
#   'wrong': 1,
#   'privat': 1,
#   'outsid': 1,
#   'room': 1,
#   'seriou': 1,
#   'misus': 1,
#   'process': 2,
#   'actual': 2,
#   'abus': 1,
#   'cook': 2,
#   'counti': 2,
#   'altho': 1,
#   'vindic': 1,
#   'author': 1,
#   'function': 1,
#   'east': 1,
#   'st.': 1,
#   'loui': 1,
#   'sit': 1,
#   'face': 1,
#   'seven': 3,
#   'schedul': 3,
#   'week': 1,
#   '35': 1,
#   'complementari': 1,
#   'miscount': 1,
#   'vote': 3,
#   'taken': 2,
#   'one': 3,
#   'candid': 1,
#   'given': 2,
#   'anoth': 2,
#   '33d': 1,
#   '24th': 1,
#   '42d': 1,
#   '31st': 1,
#   '21st': 1,
#   '28th': 1,
#   '29th': 1,
#   '18th': 1,
#   '4th': 1,
#   '9th': 1,
#   'heard': 2,
#   'previous': 1,
#   'also': 4,
#   'claim': 1,
#   'preced': 1,
#   'lack': 1,
#   'after': 1,
#   'read': 1,
#   'discharg': 2,
#   'feb.': 2,
#   '9': 2,
#   'mammoth': 1,
#   'new': 4,
#   'medic': 14,
#   'care': 12,
#   'program': 8,
#   'wherebi': 1,
#   'social': 8,
#   'secur': 7,
#   'tax': 9,
#   '70': 1,
#   'million': 12,
#   'worker': 3,
#   'rais': 1,
#   'pay': 10,
#   'hospit': 8,
#   'bill': 5,
#   '14.2': 1,
#   '65': 2,
#   'cover': 2,
#   'railroad': 3,
#   'retir': 3,
#   'messag': 4,
#   'congress': 5,
#   'tie': 1,
#   'age': 5,
#   'larg': 1,
#   'feder': 7,
#   'financ': 3,
#   'dental': 6,
#   'scholarship': 5,
#   '20': 3,
#   'school': 9,
#   'expand': 1,
#   'child': 3,
#   'health': 8,
#   'gener': 2,
#   'research': 5,
#   'similar': 3,
#   'sponsor': 1,
#   'year': 21,
#   'senat': 6,
#   'capitol': 1,
#   'hill': 1,
#   'defeat': 1,
#   'cost': 8,
#   '$37': 2,
#   'boost': 4,
#   'payrol': 6,
#   '6': 1,
#   'per': 8,
#   'cent': 6,
#   '3': 2,
#   'employ': 1,
#   '$4,800': 1,
#   'alon': 1,
#   'base': 2,
#   '$5,000': 1,
#   '6.5': 1,
#   '3.25': 1,
#   'impos': 1,
#   'system': 3,
#   'rise': 2,
#   '7.5': 1,
#   'start': 1,
#   'jan.': 1,
#   '1': 5,
#   '1963': 2,
#   'approv': 3,
#   'levi': 1,
#   'alreadi': 1,
#   'date': 1,
#   'outlay': 1,
#   'increas': 5,
#   'offici': 2,
#   'estim': 2,
#   'annual': 1,
#   '1.5': 1,
#   'billion': 3,
#   'dollar': 8,
#   'benefit': 2,
#   'paid': 3,
#   'run': 1,
#   'both': 1,
#   'figur': 1,
#   'higher': 1,
#   'later': 2,
#   'part': 2,
#   'entail': 1,
#   '750': 1,
#   'next': 1,
#   'these': 1,
#   'nurs': 7,
#   'carri': 1,
#   'full': 2,
#   'payment': 2,
#   'stay': 2,
#   '90': 1,
#   'day': 6,
#   'ill': 2,
#   'except': 1,
#   'patient': 4,
#   '$10': 1,
#   'nine': 1,
#   '2': 1,
#   '180': 1,
#   'follow': 1,
#   'A': 2,
#   'could': 2,
#   '300': 1,
#   'paid-for': 1,
#   'unit': 1,
#   'formula': 1,
#   'allow': 1,
#   'none': 1,
#   'hospital-car': 1,
#   'credit': 1,
#   'outpati': 1,
#   'clinic': 1,
#   'diagnost': 1,
#   'servic': 4,
#   'excess': 1,
#   '$20': 1,
#   '4': 1,
#   'commun': 2,
#   'visit': 1,
#   '240': 1,
#   'note': 1,
#   'pass': 1,
#   'law': 1,
#   'provid': 2,
#   'needi': 1,
#   'call': 3,
#   'modest': 2,
#   'design': 1,
#   'need': 5,
#   'wish': 1,
#   "taxpayers'": 1,
#   'expens': 1,
#   'nevertheless': 1,
#   'stagger': 1,
#   'drain': 1,
#   'save': 1,
#   'children': 1,
#   'caus': 1,
#   'extend': 1,
#   'thi': 2,
#   'cut': 1,
#   'absolut': 2,
#   'essenti': 1,
#   'suffici': 1,
#   'deduct': 1,
#   'requir': 2,
#   'discourag': 1,
#   'maling': 1,
#   'unnecessari': 1,
#   'overcrowd': 1,
#   'medicin': 3,
#   'prepay': 1,
#   'freedom': 1,
#   'choic': 1,
#   'guarante': 1,
#   'everi': 1,
#   'choos': 1,
#   'doctor': 3,
#   "wouldn't": 1,
#   'they': 1,
#   'apart': 1,
#   "president'": 2,
#   'ambiti': 1,
#   'costli': 1,
#   'enlarg': 2,
#   "nation'": 2,
#   '92': 1,
#   '47': 1,
#   'cannot': 1,
#   'handl': 1,
#   'student': 3,
#   'load': 1,
#   'moreov': 1,
#   'mani': 1,
#   'qualifi': 1,
#   'young': 1,
#   'dentistri': 1,
#   "can't": 1,
#   'afford': 1,
#   'contribut': 2,
#   'equal': 1,
#   '$1,500': 2,
#   'one-fourth': 1,
#   'money': 1,
#   '4-year': 1,
#   '$2,000': 1,
#   'addit': 1,
#   'govern': 2,
#   '$1,000': 1,
#   'educ': 1,
#   'combin': 2,
#   '5.1': 1,
#   '21': 1,
#   '1966': 1,
#   'recommend': 2,
#   'match': 2,
#   'total': 1,
#   '700': 1,
#   'construct': 2,
#   'capac': 1,
#   'exist': 1,
#   'more': 1,
#   'area': 1,
#   'doubl': 1,
#   'present': 1,
#   'initi': 1,
#   'appropri': 1,
#   'stimulatori': 1,
#   'improv': 1,
#   'unspecifi': 2,
#   'sum': 1,
#   'experiment': 1,
#   'field': 1,
#   'fund': 2,
#   "children'": 1,
#   'bureau': 1,
#   'establish': 1,
#   'nation': 1,
#   'institut': 1,
#   'vocat': 1,
#   'rehabilit': 1,
#   'for': 1,
#   'facil': 2,
#   '540': 1,
#   '1961-62': 1,
#   'budget': 1,
#   'direct': 1,
#   'indispens': 1,
#   'element': 1,
#   'sound': 1,
#   'knowledg': 1,
#   'reaction': 2,
#   'expect': 2,
#   'congression': 1,
#   'along': 1,
#   'line': 1,
#   'legisl': 1,
#   'oppos': 1,
#   'place': 1,
#   'aged-car': 1,
#   'critic': 1,
#   'those': 1,
#   'back': 1,
#   'hail': 1,
#   'republican': 2,
#   'leader': 3,
#   'dirksen': 1,
#   'ill.': 1,
#   'halleck': 2,
#   'ind.': 1,
#   'persuad': 1,
#   'chang': 1,
#   'opposit': 1,
#   'compulsori': 1,
#   'insur': 1,
#   'voluntari': 1,
#   'enact': 1,
#   'speaker': 1,
#   'sam': 1,
#   'rayburn': 1,
#   'D.': 2,
#   'tex.': 1,
#   'mighti': 1,
#   'fine': 1,
#   'thing': 1,
#   'predict': 1,
#   'fate': 1,
#   'hastili': 1,
#   'pressur': 1,
#   'tonight': 1,
#   'confirm': 1,
#   'robert': 1,
#   'C.': 1,
#   'weaver': 1,
#   'onli': 1,
#   '11': 1,
#   'floor': 2,
#   'record': 1,
#   'number': 1,
#   'scatter': 1,
#   'aye': 1,
#   'noe': 1,
#   'customari': 1,
#   'ignor': 1,
#   'order': 1,
#   'speed': 1,
#   'negro': 1,
#   'agenc': 1,
#   'presidenti': 1,
#   'appoint': 1,
#   'includ': 1,
#   'cabinet': 2,
#   'rank': 1,
#   'immedi': 1,
#   'action': 1,
#   'least': 1,
#   'hour': 1,
#   'delay': 1,
#   'report': 1,
#   'enforc': 2,
#   'sen.': 1,
#   'wayn': 1,
#   'mors': 1,
#   'ore.': 1,
#   'connect': 1,
#   "eisenhower'": 1,
#   'select': 1,
#   '1953': 1,
#   "kennedy'": 1,
#   '1961': 1},
#  'ca04': {'oslo': 5,
#   'the': 19,
#   'posit': 2,
#   'element': 1,
#   'emerg': 1,
#   'meet': 4,
#   'north': 1,
#   'atlant': 1,
#   'treati': 2,
#   'organ': 4,
#   'foreign': 6,
#   'minist': 2,
#   'freer': 1,
#   'franker': 1,
#   'wider': 1,
#   'discuss': 2,
#   'anim': 1,
#   'much': 3,
#   'better': 2,
#   'mutual': 1,
#   'understand': 3,
#   'past': 2,
#   'thi': 5,
#   'work': 2,
#   'session': 1,
#   'natur': 1,
#   'proceed': 1,
#   'along': 1,
#   'rout': 1,
#   'step': 4,
#   'without': 3,
#   'dramat': 1,
#   'chang': 3,
#   'In': 4,
#   'met': 1,
#   'climat': 1,
#   'candor': 1,
#   'made': 4,
#   'genuin': 1,
#   'attempt': 2,
#   'get': 2,
#   'inform': 2,
#   'one': 6,
#   "another'": 1,
#   'problem': 6,
#   'atmospher': 1,
#   'particularli': 1,
#   'notic': 3,
#   'relat': 3,
#   'concern': 3,
#   '``': 13,
#   'colonialist': 1,
#   "''": 12,
#   'power': 2,
#   'never': 4,
#   'long': 2,
#   'time': 5,
#   'nightmar': 1,
#   'clash': 1,
#   'troubl': 2,
#   'africa': 1,
#   'exacerb': 1,
#   'difficulti': 1,
#   'tragedi': 1,
#   'face': 1,
#   'alli': 4,
#   'intellectu': 1,
#   'emot': 1,
#   'disapprov': 1,
#   'circumst': 1,
#   'brought': 1,
#   'conspicu': 1,
#   'absenc': 1,
#   'explos': 2,
#   'avoid': 1,
#   'case': 2,
#   'portug': 1,
#   'week': 2,
#   'ago': 3,
#   'rumor': 1,
#   'readi': 2,
#   'walk': 1,
#   'nato': 7,
#   'council': 5,
#   'critic': 3,
#   'angola': 2,
#   'polici': 14,
#   'prove': 2,
#   'harsh': 1,
#   'relax': 1,
#   'tension': 1,
#   'gener': 6,
#   'remark': 1,
#   'courteou': 1,
#   'explan': 1,
#   'left': 1,
#   'basic': 2,
#   'unchang': 1,
#   'there': 4,
#   'even': 4,
#   'bitter': 1,
#   'surpris': 1,
#   'UN': 1,
#   'assembl': 1,
#   "members'": 1,
#   'vote': 1,
#   'sinc': 3,
#   'new': 5,
#   'ad': 1,
#   'hoc': 1,
#   'committe': 5,
#   'set': 3,
#   'futur': 2,
#   'topic': 1,
#   'advanc': 1,
#   'canada': 1,
#   'alon': 1,
#   'somewhat': 2,
#   'car': 1,
#   'back': 2,
#   'track': 1,
#   'behind': 1,
#   'locomot': 1,
#   'norway': 1,
#   'despit': 3,
#   'daili': 1,
#   'limit': 2,
#   'manifest': 1,
#   'atom': 1,
#   'arm': 2,
#   'heart': 1,
#   'northernmost': 1,
#   'capit': 1,
#   'allianc': 3,
#   'today': 1,
#   'closer': 1,
#   'line': 1,
#   'On': 1,
#   'neg': 1,
#   'side': 1,
#   'balanc': 1,
#   'sheet': 1,
#   'must': 2,
#   'disappoint': 1,
#   'unit': 14,
#   'state': 21,
#   'leadership': 3,
#   'evid': 1,
#   'hope': 2,
#   'diplomat': 3,
#   'describ': 1,
#   'tenor': 1,
#   'secretari': 6,
#   'dean': 1,
#   "rusk'": 3,
#   'speech': 2,
#   'inconclus': 1,
#   'but': 9,
#   'hasten': 1,
#   'add': 1,
#   'alway': 1,
#   'clear': 2,
#   'mr.': 4,
#   'analysi': 1,
#   'variou': 1,
#   'global': 2,
#   'danger': 2,
#   'point': 1,
#   'setback': 2,
#   'west': 1,
#   'may': 2,
#   'mere': 1,
#   'mean': 1,
#   'administr': 22,
#   'yet': 1,
#   'firmli': 1,
#   'fix': 1,
#   'exploratori': 2,
#   'mood': 1,
#   'A': 1,
#   'certain': 1,
#   'vagu': 1,
#   'also': 4,
#   'caus': 1,
#   'tactic': 1,
#   'appreci': 1,
#   'fact': 2,
#   'present': 1,
#   'semipubl': 1,
#   'affair': 1,
#   'fewer': 1,
#   'six': 1,
#   'soviet': 3,
#   'correspond': 3,
#   'accredit': 1,
#   'impress': 1,
#   'nevertheless': 1,
#   'given': 2,
#   'three': 2,
#   'day': 1,
#   'person': 2,
#   'popular': 1,
#   'deleg': 1,
#   'came': 1,
#   'tent': 1,
#   'frame': 1,
#   'mind': 1,
#   'listen': 1,
#   'learn': 1,
#   'enunci': 1,
#   'firm': 1,
#   'scale': 1,
#   'detail': 1,
#   'applic': 1,
#   'individu': 1,
#   'spot': 1,
#   'first': 4,
#   'gave': 2,
#   'idea': 2,
#   'tremend': 1,
#   'march': 2,
#   'event': 1,
#   'insid': 1,
#   'outsid': 1,
#   'preoccupi': 1,
#   'four': 1,
#   'month': 3,
#   'core': 1,
#   'reiter': 1,
#   "states'": 1,
#   'profound': 1,
#   'attach': 1,
#   'cornerston': 1,
#   'announc': 2,
#   'five': 1,
#   'nuclear': 3,
#   'submarin': 1,
#   'eventu': 1,
#   "nato'": 1,
#   'dispos': 1,
#   'european': 1,
#   'water': 2,
#   'solemnli': 1,
#   'repeat': 1,
#   'warn': 1,
#   'union': 2,
#   'stand': 1,
#   'anoth': 3,
#   'berlin': 1,
#   'affirm': 1,
#   'taken': 1,
#   'whole': 1,
#   'conflict': 2,
#   'survey': 1,
#   "secretary'": 1,
#   'greatest': 1,
#   'achiev': 2,
#   'perhap': 1,
#   'rekindl': 1,
#   'realiz': 1,
#   'east-west': 1,
#   'friction': 1,
#   'wherev': 1,
#   'take': 3,
#   'place': 1,
#   'around': 1,
#   'globe': 1,
#   'essenc': 1,
#   'two': 1,
#   'entir': 1,
#   'differ': 1,
#   'societi': 1,
#   'treat': 1,
#   'regard': 1,
#   'geograph': 1,
#   'distanc': 1,
#   'lack': 1,
#   'appar': 2,
#   'connect': 1,
#   'annual': 1,
#   'spring': 1,
#   'impetu': 1,
#   'main': 1,
#   'direct': 2,
#   'deeper': 1,
#   'polit': 3,
#   'consult': 1,
#   'within': 1,
#   'use': 2,
#   'econom': 3,
#   'cooper': 2,
#   'develop': 2,
#   'ratifi': 1,
#   'method': 1,
#   'coordin': 2,
#   'aid': 7,
#   'underdevelop': 1,
#   'countri': 4,
#   'need': 2,
#   'strengthen': 2,
#   'convent': 2,
#   'forc': 2,
#   'well': 1,
#   'mainten': 1,
#   'deterr': 1,
#   'increas': 2,
#   'threshold': 1,
#   'call': 3,
#   "alliance'": 1,
#   'difficult': 1,
#   'come': 1,
#   'each': 1,
#   'carri': 1,
#   'oblig': 1,
#   'laid': 2,
#   'complet': 1,
#   'fulfil': 1,
#   'washington': 2,
#   'kennedi': 8,
#   'move': 2,
#   'haltingli': 1,
#   'toward': 2,
#   'geneva': 3,
#   'confer': 4,
#   'lao': 17,
#   'seriou': 1,
#   'debat': 1,
#   'erupt': 1,
#   'littl': 1,
#   'optim': 1,
#   'communist': 13,
#   'docil': 1,
#   'tabl': 1,
#   'militari': 5,
#   'action': 2,
#   'ground': 1,
#   'depart': 1,
#   'offici': 2,
#   'explain': 1,
#   'mainli': 1,
#   'interest': 1,
#   'intern': 2,
#   'inspect': 1,
#   'system': 1,
#   'prevent': 2,
#   'base': 1,
#   'attack': 2,
#   'neighbor': 2,
#   'thailand': 2,
#   'south': 2,
#   'viet': 2,
#   'nam': 2,
#   'they': 2,
#   'count': 1,
#   'neutral': 2,
#   'attend': 1,
#   'cabinet': 1,
#   'would': 9,
#   'becom': 1,
#   'domin': 2,
#   'accept': 3,
#   'formula': 1,
#   'found': 1,
#   'possibl': 1,
#   'modifi': 1,
#   'inclin': 1,
#   'de': 1,
#   'facto': 1,
#   'cease-fir': 2,
#   'rather': 1,
#   'continu': 1,
#   'insist': 2,
#   'verif': 1,
#   'control': 1,
#   'commiss': 1,
#   'particip': 1,
#   'modif': 1,
#   'felt': 2,
#   'compel': 1,
#   'make': 1,
#   'It': 3,
#   'excus': 1,
#   'chain': 1,
#   'reaction': 1,
#   'error': 1,
#   'previou': 1,
#   'it': 1,
#   'spokesmen': 2,
#   'enough': 1,
#   'institut': 2,
#   'reform': 2,
#   'area': 1,
#   '--': 2,
#   'immedi': 1,
#   'confront': 1,
#   'show': 3,
#   'gain': 1,
#   'free': 1,
#   'world': 1,
#   'question': 3,
#   'aris': 1,
#   'how': 1,
#   'effect': 2,
#   'decis': 1,
#   'deal': 1,
#   'aggress': 1,
#   'former': 1,
#   'vice-presid': 1,
#   'richard': 1,
#   'M.': 1,
#   'nixon': 3,
#   'detroit': 1,
#   'firmer': 1,
#   'tougher': 2,
#   'He': 2,
#   'feel': 2,
#   'presid': 7,
#   "kennedy'": 1,
#   'tendenc': 1,
#   'conciliatori': 1,
#   'gop': 1,
#   'restrain': 2,
#   'gallup': 1,
#   'poll': 1,
#   'find': 2,
#   'republican': 6,
#   'congress': 2,
#   'underst': 1,
#   'situat': 2,
#   'see': 1,
#   'hardli': 1,
#   'rais': 1,
#   'whether': 1,
#   'amateurish': 1,
#   'monument': 1,
#   'blunder': 1,
#   'cuba': 4,
#   'senat': 4,
#   'told': 1,
#   'constantli': 1,
#   'ask': 3,
#   'score': 1,
#   'hi': 2,
#   'repli': 1,
#   'said': 3,
#   'agre': 1,
#   'uniti': 1,
#   'let': 1,
#   'other': 1,
#   'wisdom': 1,
#   'serv': 1,
#   'thruston': 1,
#   'B.': 1,
#   'morton': 1,
#   'R': 1,
#   'kentucki': 1,
#   'chairman': 2,
#   'nation': 6,
#   'held': 1,
#   'respons': 2,
#   'outcom': 1,
#   'coalit': 1,
#   'govern': 4,
#   'suscept': 1,
#   'assail': 1,
#   '70': 1,
#   'harvard': 1,
#   'boston': 1,
#   'univers': 1,
#   'brandei': 1,
#   'massachusett': 1,
#   'technolog': 1,
#   'educ': 2,
#   'detent': 2,
#   'urg': 1,
#   'group': 2,
#   'plead': 1,
#   'give': 2,
#   'support': 3,
#   'invas': 1,
#   'exil': 1,
#   'recommend': 2,
#   'seek': 1,
#   'instead': 1,
#   'detach': 1,
#   'castro': 1,
#   'regim': 1,
#   'bloc': 1,
#   'resumpt': 1,
#   'trade': 1,
#   'concentr': 1,
#   'construct': 1,
#   'effort': 7,
#   'elimin': 1,
#   'part': 2,
#   'latin': 1,
#   'america': 1,
#   'social': 1,
#   'condit': 1,
#   'totalitarian': 1,
#   'feed': 1,
#   'oppos': 1,
#   'intervent': 1,
#   'specif': 1,
#   'provoc': 2,
#   'clearli': 1,
#   'ship': 1,
#   'toler': 1,
#   'until': 1,
#   'cuban': 1,
#   'fiasco': 1,
#   'victori': 1,
#   'almost': 1,
#   'observ': 1,
#   'blend': 1,
#   'program': 3,
#   'respect': 1,
#   'opinion': 1,
#   'voic': 1,
#   'professor': 1,
#   'plan': 2,
#   'revamp': 2,
#   'veri': 1,
#   'earli': 2,
#   'kremlin': 1,
#   'channel': 1,
#   'high': 1,
#   'sourc': 1,
#   'disclos': 1,
#   'react': 1,
#   'eisenhow': 2,
#   'form': 1,
#   'period': 1,
#   'strenuou': 1,
#   'remov': 2,
#   'pin': 1,
#   'prick': 1,
#   'statement': 2,
#   'test': 1,
#   'ban': 1,
#   'negoti': 1,
#   'review': 1,
#   'thu': 1,
#   'far': 1,
#   'kind': 1,
#   'greater': 1,
#   'emphasi': 1,
#   'encourag': 2,
#   'recipi': 1,
#   'look': 1,
#   'determin': 2,
#   'sail': 1,
#   'naval': 1,
#   'fleet': 1,
#   'southeast': 2,
#   'asian': 1,
#   'useless': 1,
#   'gestur': 1,
#   'again': 1,
#   'freez': 1,
#   'pathet': 2,
#   'faster': 1,
#   'rate': 1,
#   'and': 1,
#   'sever': 1,
#   'went': 1,
#   'territori': 1,
#   'expos': 1,
#   'huge': 1,
#   'build-up': 1,
#   'acclaim': 1,
#   'perform': 1,
#   'great': 1,
#   'servic': 1,
#   'matter': 2,
#   'asia': 1,
#   'seato': 2,
#   'steam': 1,
#   'prepar': 1,
#   'conting': 1,
#   'cope': 2,
#   'loss': 1,
#   'suffici': 1,
#   'want': 1,
#   'risk': 1,
#   'all-out': 1,
#   'war': 1,
#   'some': 1,
#   'disagre': 1,
#   'howev': 1,
#   'complic': 1,
#   'conclud': 1,
#   'ill': 1,
#   'suit': 1,
#   'unlik': 1,
#   'declar': 2,
#   'favor': 1,
#   'pro-western': 2,
#   'help': 1,
#   'revolt': 1,
#   'souvanna': 3,
#   'phouma': 2,
#   'neutralist': 1,
#   'appear': 1,
#   'spark': 1,
#   'fight': 1,
#   'spirit': 1,
#   'royal': 1,
#   'armi': 1,
#   'certainli': 1,
#   'energi': 1,
#   'display': 1,
#   'hilt': 1,
#   'If': 1,
#   'ever': 1,
#   'could': 1,
#   'altern': 1,
#   'princ': 2,
#   'trust': 1,
#   'gradual': 1,
#   'relinquish': 1,
#   'factor': 1,
#   'J.': 1,
#   'W.': 1,
#   'fulbright': 1,
#   'D': 1,
#   'arkansa': 1,
#   '25': 1,
#   'er': 1,
#   'year': 3,
#   'half': 2,
#   'white': 1,
#   'hous': 1,
#   'extraordinari': 1,
#   'check': 1,
#   'rapid': 1,
#   'growth': 1,
#   'juvenil': 5,
#   'delinqu': 3,
#   'deepli': 1,
#   'upon': 2,
#   'vital': 1,
#   'import': 1,
#   'assert': 1,
#   'field': 1,
#   'issu': 1,
#   'execut': 2,
#   'order': 1,
#   'establish': 1,
#   "president'": 1,
#   'crime': 3,
#   'assist': 3,
#   'citizen': 1,
#   'advisori': 1,
#   'recogn': 1,
#   'author': 1,
#   'enact': 1,
#   'legisl': 1,
#   'provid': 1,
#   'feder': 3,
#   'grant': 1,
#   'specifi': 1,
#   'combat': 1,
#   'disturb': 1,
#   'trend': 1,
#   'offens': 1,
#   'multipli': 1,
#   'attorney': 2,
#   'health': 1,
#   'welfar': 1,
#   'labor': 1,
#   'local': 1,
#   'commun': 1,
#   'simultan': 1,
#   'thursday': 1,
#   'appoint': 1,
#   'david': 1,
#   'L.': 1,
#   'hackett': 1,
#   'special': 1,
#   'director': 1,
#   'youth': 1,
#   'sens': 1,
#   'urgenc': 1,
#   'stem': 1,
#   'court': 1,
#   'arrest': 2,
#   'doubl': 1,
#   '1948': 1,
#   'offend': 1,
#   'among': 1,
#   'report': 1,
#   'bureau': 1,
#   'investig': 1,
#   '1959': 1,
#   'burglari': 1,
#   'larceni': 1,
#   'involv': 1,
#   '18': 1,
#   'age': 1},
#  'ca05': {'east': 4,
#   'provid': 10,
#   'organ': 4,
#   'civil': 6,
#   'defens': 7,
#   'setup': 1,
#   'begin': 1,
#   'appoint': 3,
#   'full-tim': 6,
#   'director': 8,
#   'raymond': 2,
#   'H.': 2,
#   'hawksley': 10,
#   'present': 6,
#   'citi': 15,
#   'CD': 7,
#   'head': 1,
#   'believ': 4,
#   'mr.': 25,
#   'said': 31,
#   'yesterday': 5,
#   'would': 20,
#   'will': 3,
#   'go': 4,
#   'council': 16,
#   '``': 25,
#   'anyon': 1,
#   'els': 1,
#   'local': 10,
#   "''": 24,
#   'outlin': 1,
#   'propos': 2,
#   'earliest': 1,
#   'possibl': 6,
#   'time': 5,
#   'program': 4,
#   "state'": 1,
#   'gener': 6,
#   'treasur': 1,
#   'part-tim': 1,
#   'last': 7,
#   'nine': 2,
#   'year': 3,
#   'He': 15,
#   'interest': 2,
#   'name': 3,
#   'note': 1,
#   'presid': 4,
#   'kennedi': 1,
#   'hand': 3,
#   'depart': 2,
#   'major': 2,
#   'respons': 2,
#   "nation'": 1,
#   'feder': 3,
#   'govern': 7,
#   'pay': 2,
#   'half': 4,
#   'salari': 2,
#   'express': 2,
#   'opinion': 4,
#   'could': 3,
#   'hire': 1,
#   '$3,500': 1,
#   'put': 1,
#   'amount': 1,
#   'match': 2,
#   'fund': 2,
#   'basi': 2,
#   'defray': 1,
#   'cost': 2,
#   'number': 1,
#   'qualifi': 1,
#   'resid': 4,
#   'take': 4,
#   'job': 1,
#   'one': 6,
#   'men': 1,
#   'former': 1,
#   'fire': 2,
#   'chief': 1,
#   'john': 2,
#   'A.': 3,
#   'laughlin': 1,
#   'along': 1,
#   'headquart': 1,
#   'pertin': 1,
#   'inform': 3,
#   'central': 5,
#   'advantag': 2,
#   'come': 6,
#   'becom': 2,
#   'elig': 2,
#   'appli': 1,
#   'financi': 1,
#   'aid': 2,
#   'purchas': 1,
#   'equip': 1,
#   'need': 3,
#   'sound': 1,
#   'also': 2,
#   'obtain': 5,
#   'procur': 1,
#   'item': 1,
#   'radio': 1,
#   'siren': 1,
#   'rescu': 3,
#   'truck': 3,
#   'use': 1,
#   'two': 2,
#   'similar': 2,
#   'vehicl': 1,
#   'sever': 4,
#   'ago': 1,
#   'detail': 1,
#   'station': 2,
#   'assign': 1,
#   'riversid': 2,
#   'section': 1,
#   'rumford': 1,
#   'area': 1,
#   'speak': 2,
#   'statu': 1,
#   'bet': 1,
#   'person': 2,
#   'hundr': 1,
#   'know': 3,
#   'event': 1,
#   'enemi': 1,
#   'attack': 2,
#   'the': 12,
#   'narragansett': 1,
#   'race': 1,
#   'track': 4,
#   'ground': 1,
#   'assembl': 6,
#   'point': 2,
#   'drive-in': 1,
#   'theater': 1,
#   'seekonk': 2,
#   'anoth': 1,
#   'critic': 1,
#   'case': 1,
#   'air': 1,
#   'such': 1,
#   'vital': 2,
#   'made': 2,
#   'avail': 1,
#   'public': 5,
#   'frequent': 1,
#   'regular': 1,
#   'interv': 1,
#   'If': 1,
#   'fail': 1,
#   'consid': 1,
#   'plan': 3,
#   'call': 4,
#   'meet': 4,
#   'earli': 1,
#   'septemb': 2,
#   'develop': 2,
#   'first': 3,
#   'thing': 1,
#   'class': 1,
#   'other': 1,
#   'step': 3,
#   'drift': 1,
#   'level': 1,
#   'rhode': 3,
#   'island': 3,
#   'examin': 1,
#   'sunday': 8,
#   'sale': 5,
#   'law': 12,
#   'revis': 2,
#   'mind': 2,
#   'governor': 5,
#   'nott': 4,
#   'night': 2,
#   'committe': 3,
#   'make': 2,
#   'studi': 6,
#   'recommend': 1,
#   'chang': 1,
#   'next': 2,
#   'session': 3,
#   "governor'": 1,
#   'move': 1,
#   'so-cal': 1,
#   'blue': 2,
#   'controversi': 1,
#   'came': 1,
#   'form': 2,
#   'letter': 1,
#   'miss': 3,
#   'mari': 1,
#   'R.': 1,
#   'grant': 3,
#   'deputi': 1,
#   'clerk': 1,
#   'fall': 3,
#   'A': 4,
#   'copi': 1,
#   'releas': 1,
#   'press': 1,
#   'respond': 1,
#   'resolut': 4,
#   'adopt': 2,
#   'juli': 2,
#   '10': 2,
#   'sent': 1,
#   'state': 6,
#   'hous': 1,
#   'urg': 1,
#   'complet': 2,
#   'eye': 1,
#   'legislatur': 1,
#   'while': 1,
#   'suggest': 4,
#   'legisl': 2,
#   'might': 3,
#   'perform': 1,
#   'review': 1,
#   'instead': 2,
#   'matter': 1,
#   'atty.': 1,
#   'gen.': 1,
#   'J.': 1,
#   'joseph': 1,
#   'nugent': 1,
#   'get': 1,
#   'benefit': 1,
#   'view': 2,
#   "nugent'": 1,
#   'cooper': 1,
#   'I': 6,
#   'expect': 3,
#   'hold': 2,
#   'hear': 1,
#   'religi': 1,
#   'labor': 1,
#   'special-interest': 1,
#   'group': 7,
#   'affect': 1,
#   'wrote': 1,
#   'concern': 2,
#   'continu': 1,
#   'problem': 1,
#   'confront': 1,
#   'enforc': 4,
#   'offic': 2,
#   'result': 1,
#   'regul': 1,
#   'attorney': 1,
#   'advis': 2,
#   'polic': 4,
#   'duti': 1,
#   'should': 1,
#   'evid': 1,
#   'shirk': 1,
#   'situat': 1,
#   'there': 1,
#   'activ': 1,
#   'across': 1,
#   'line': 1,
#   'massachusett': 1,
#   'recent': 2,
#   'week': 5,
#   'toward': 1,
#   'statut': 1,
#   'bay': 1,
#   'date': 1,
#   'back': 3,
#   'instanc': 1,
#   'coloni': 1,
#   'limit': 2,
#   'type': 2,
#   'merchandis': 1,
#   'may': 3,
#   'sold': 1,
#   'sabbath': 1,
#   'especi': 1,
#   'food': 1,
#   'place': 1,
#   'list': 1,
#   'neighborhood': 1,
#   'groceri': 1,
#   'varieti': 1,
#   'store': 2,
#   'allow': 3,
#   'busi': 2,
#   'day': 5,
#   'chanc': 1,
#   'compet': 1,
#   'larg': 2,
#   'supermarket': 2,
#   "council'": 1,
#   'small': 1,
#   'shop': 2,
#   'must': 4,
#   'retain': 1,
#   'essenti': 2,
#   'servic': 1,
#   'commun': 2,
#   'accord': 1,
#   'ad': 3,
#   'sourc': 1,
#   'livelihood': 1,
#   'thousand': 1,
#   'neighbor': 1,
#   'It': 2,
#   'declar': 2,
#   'licens': 1,
#   'great': 1,
#   'revenu': 1,
#   'factori': 1,
#   'outlet': 1,
#   'they': 1,
#   'oper': 2,
#   'volum': 1,
#   'contend': 1,
#   'liber': 1,
#   'conserv': 1,
#   'parti': 8,
#   '--': 6,
#   'democrat': 2,
#   'republican': 1,
#   'divorc': 1,
#   'independ': 1,
#   'georg': 1,
#   'reama': 5,
#   'nation': 3,
#   'known': 1,
#   'labor-manag': 1,
#   'expert': 1,
#   'told': 4,
#   'rotari': 1,
#   'club': 1,
#   'luncheon': 1,
#   'sheraton-biltmor': 1,
#   'hotel': 1,
#   'peopl': 1,
#   'countri': 1,
#   'want': 2,
#   'welfar': 1,
#   'free': 2,
#   'enterpris': 2,
#   'system': 2,
#   'regroup': 1,
#   'forc': 1,
#   'averag': 1,
#   'voter': 1,
#   'better': 1,
#   'pull': 1,
#   'right': 3,
#   'lever': 1,
#   'elect': 4,
#   'confess': 1,
#   'member': 3,
#   'socialist': 6,
#   '1910': 3,
#   'that': 2,
#   'young': 1,
#   'man': 1,
#   'machinist': 1,
#   'toolmak': 1,
#   'trade': 1,
#   'some': 2,
#   'fellow': 1,
#   'worker': 2,
#   'groom': 1,
#   'lawyer': 1,
#   'steer': 2,
#   'util': 1,
#   'pool': 1,
#   'resourc': 1,
#   'without': 2,
#   'ever': 1,
#   'gain': 1,
#   'victori': 1,
#   'origin': 1,
#   'pass': 1,
#   'retir': 2,
#   'vice': 1,
#   'american': 1,
#   'screw': 1,
#   'co.': 1,
#   '1955': 1,
#   'both': 1,
#   'us': 2,
#   'five': 1,
#   'per': 1,
#   'cent': 1,
#   'growth': 1,
#   'gross': 1,
#   'product': 1,
#   'neither': 1,
#   'achiev': 1,
#   'favor': 3,
#   'wage': 1,
#   'increas': 4,
#   'manufactur': 1,
#   'caught': 1,
#   'profit': 1,
#   'squeez': 1,
#   'rais': 1,
#   'condit': 1,
#   'higher': 1,
#   'price': 1,
#   'indic': 3,
#   'way': 1,
#   'turn': 1,
#   'philosophi': 1,
#   'divid': 1,
#   'everyth': 1,
#   'far': 1,
#   'realli': 1,
#   'engag': 1,
#   'industri': 1,
#   'relat': 1,
#   'counsel': 1,
#   'petit': 3,
#   'bear': 1,
#   'signatur': 4,
#   '1,700': 1,
#   'johnston': 4,
#   'taxpay': 1,
#   'town': 9,
#   'hope': 2,
#   'home': 6,
#   'rule': 6,
#   'charter': 11,
#   'william': 1,
#   'martinelli': 7,
#   'chairman': 2,
#   'citizen': 4,
#   'transfer': 1,
#   'left': 1,
#   'vote': 6,
#   'accept': 1,
#   'fortin': 1,
#   'sr.': 1,
#   'refer': 1,
#   'board': 2,
#   'canvass': 2,
#   'verif': 1,
#   'within': 3,
#   'happen': 1,
#   'post': 2,
#   'explain': 2,
#   'enough': 1,
#   'assur': 2,
#   'schedul': 2,
#   'commiss': 3,
#   '70': 1,
#   'establish': 1,
#   'procedur': 2,
#   'issu': 1,
#   '60': 1,
#   'work': 1,
#   'differ': 1,
#   'aros': 1,
#   'P.': 1,
#   'bourcier': 3,
#   'solicitor': 2,
#   'exact': 1,
#   'manner': 1,
#   'handl': 1,
#   'special': 3,
#   'consult': 1,
#   'superior': 1,
#   'court': 3,
#   'justic': 1,
#   'receiv': 1,
#   'correct': 1,
#   'method': 1,
#   'report': 1,
#   'soon': 1,
#   '24': 1,
#   'strategi': 1,
#   'movement': 4,
#   'candid': 2,
#   'undoubtedli': 1,
#   'endors': 1,
#   'after': 1,
#   'inspir': 1,
#   'think': 1,
#   'certainli': 1,
#   'follow': 2,
#   'spearhead': 1,
#   'surpris': 1,
#   '30': 1,
#   'run': 1,
#   'requir': 1,
#   'non-partisan': 1,
#   'ballot': 1,
#   'our': 1,
#   'immedi': 1,
#   'goal': 1,
#   'awar': 1,
#   'tell': 1,
#   'mean': 3,
#   'timet': 1,
#   'opposit': 2,
#   'start': 1,
#   'heard': 1,
#   'spokesmen': 1,
#   "town'": 1,
#   'insurg': 1,
#   'leadership': 1,
#   'model': 1,
#   'municip': 1,
#   'leagu': 1,
#   'misunderstand': 1,
#   'real': 1,
#   'cite': 1,
#   'factor': 1,
#   'caus': 1,
#   'term': 1,
#   'fals': 1,
#   'pretens': 1,
#   'signer': 1,
#   'affix': 1,
#   'learn': 1,
#   'tax': 1,
#   'consent': 1,
#   'provis': 1,
#   'includ': 1,
#   'sanitari': 1,
#   'district': 2,
#   'sewer': 1,
#   'action': 1,
#   'new': 1,
#   'ordin': 3,
#   'permit': 1,
#   'motorist': 1,
#   'plead': 1,
#   'guilti': 1,
#   'minor': 2,
#   'traffic': 1,
#   'offens': 4,
#   'fine': 1,
#   'taken': 2,
#   "monday'": 1,
#   'north': 1,
#   'frank': 1,
#   'sanantonio': 1,
#   'ask': 1,
#   'formal': 1,
#   'request': 1,
#   'michael': 1,
#   'abatuno': 1,
#   'draft': 1,
#   'At': 2,
#   'author': 1,
#   'effect': 1,
#   'noth': 1,
#   'done': 1,
#   'yet': 1,
#   'enabl': 1,
#   'sixth': 1,
#   'disposit': 1,
#   'hesit': 1,
#   'prosecut': 1,
#   'heavi': 1,
#   'involv': 1,
#   'even': 1,
#   'simplest': 1},
#  'ca06': {'plainfield': 2,
#   '--': 8,
#   'jame': 2,
#   'P.': 1,
#   'mitchel': 13,
#   'sen.': 5,
#   'walter': 1,
#   'H.': 1,
#   'jone': 11,
#   'r-bergen': 1,
#   'last': 6,
#   'night': 3,
#   'disagre': 1,
#   'valu': 1,
#   'use': 5,
#   'campaign': 12,
#   'issu': 10,
#   'remark': 3,
#   'richard': 3,
#   'J.': 5,
#   'hugh': 11,
#   'democrat': 8,
#   'gubernatori': 5,
#   'candid': 12,
#   'gop': 3,
#   '``': 36,
#   'carcass': 3,
#   'eisenhow': 8,
#   'republican': 22,
#   "''": 31,
#   'wayn': 1,
#   'dumont': 2,
#   'jr.': 1,
#   'r-warren': 1,
#   'mention': 2,
#   'three': 2,
#   'spoke': 2,
#   'stagger': 1,
#   'interv': 1,
#   '100': 1,
#   'person': 2,
#   'park': 2,
#   'hotel': 2,
#   'the': 11,
#   'controversi': 1,
#   'first': 2,
#   'made': 5,
#   'sunday': 2,
#   'westfield': 4,
#   'young': 1,
#   'club': 4,
#   'cocktail': 1,
# ...
#   'suppos': 1,
#   'know': 1,
#   'recal': 1,
#   'around': 1,
#   'hard': 1,
#   'chicken': 5,
#   'cadillac': 1,
#   'use': 4,
#   '6-ounc': 1,
#   'breast': 5,
#   'guest': 3,
#   'salt': 1,
#   'pepper': 1,
#   'dip': 1,
#   'melt': 1,
#   'butter': 2,
#   'roll': 1,
#   'flour': 1,
#   'side': 2,
#   '2-inch': 1,
#   'deep': 1,
#   'bake': 4,
#   'pan': 1,
#   'slowli': 2,
#   'hour': 2,
#   '250-275': 1,
#   'F.': 2,
#   'lightli': 1,
#   'brown': 2,
#   'add': 1,
#   'warm': 2,
#   'cream': 1,
#   'onion': 1,
#   'juic': 1,
#   'half': 1,
#   'cover': 1,
#   'least': 1,
#   'one-half': 1,
#   'longer': 1,
#   'while': 1,
#   'saut': 1,
#   'mushroom': 1,
#   'fresh': 1,
#   'can': 1,
#   'sprinkl': 2,
#   'top': 3,
#   'thin': 1,
#   'slice': 1,
#   'slow-bak': 1,
#   'ham': 2,
#   'thompson': 1,
#   'seedless': 1,
#   'grape': 1,
#   'leav': 1,
#   'call': 3,
#   'pontiac': 1,
#   'contemporari': 5,
#   'furnitur': 3,
#   'neither': 1,
#   'danish': 1,
#   'straight-lin': 1,
#   'modern': 2,
#   'sculptur': 2,
#   'pattern': 1,
#   'facet': 1,
#   'warmth': 3,
#   'digniti': 2,
#   'effect': 1,
#   'utter': 1,
#   'comfort': 2,
#   'livabl': 1,
#   'that': 1,
#   'goal': 1,
#   'collect': 7,
#   'introduc': 1,
#   'month': 1,
#   'though': 1,
#   'avant': 1,
#   'gard': 1,
#   'indic': 2,
#   'might': 1,
#   'boxi': 1,
#   "'20'": 1,
#   "'40'": 1,
#   'manufactur': 2,
#   'chose': 2,
#   'take': 1,
#   'approach': 3,
#   'these': 1,
#   'heritag': 3,
#   'drexel': 2,
#   'produc': 1,
#   'exactli': 1,
#   'match': 2,
#   'everi': 1,
#   'correl': 1,
#   'could': 1,
#   'stand': 1,
#   'alon': 1,
#   'shown': 2,
#   'sanger-harri': 1,
#   "anderson'": 1,
#   'studio': 1,
#   'perhap': 1,
#   'differ': 1,
#   'wood': 2,
#   'decor': 5,
#   'ever': 1,
#   'assembl': 1,
#   'togeth': 1,
#   'perennian': 2,
#   'good': 1,
#   'today': 1,
#   'tomorrow': 1,
#   'qualiti': 1,
#   'truli': 1,
#   'avoid': 1,
#   'monotoni': 1,
#   'ident': 1,
#   'walnut': 2,
#   'wormi': 1,
#   'chestnut': 1,
#   'pecan': 1,
#   'varieti': 2,
#   'burl': 2,
#   'hand-woven': 1,
#   'philippin': 1,
#   'cane': 2,
#   'ceram': 2,
#   'tile': 2,
#   'marbl': 1,
#   'emphas': 1,
#   'feel': 1,
#   'textur': 1,
#   'perman': 1,
#   'fit': 1,
#   'room': 1,
#   'floor': 1,
#   'brick': 1,
#   'panel': 7,
#   'wall': 1,
#   'window': 1,
#   'bring': 2,
#   'outdoor': 1,
#   'custom-design': 1,
#   'offer': 2,
#   'vital': 1,
#   'composit': 3,
#   "titche'": 1,
#   'realist': 1,
#   'matur': 2,
#   'variat': 1,
#   'round': 1,
#   'post': 1,
#   'give': 1,
#   'soft': 1,
#   'door': 1,
#   'inset': 1,
#   'plu': 1,
#   'soften': 1,
#   'arch': 3,
#   'inlaid': 1,
#   'macassar': 1,
#   'acacia': 3,
#   'high-leg': 1,
#   'buffet': 1,
#   'provid': 1,
#   'easy-to-reach': 1,
#   'small': 1,
#   'tuck': 1,
#   'recess': 1,
#   '60-inch': 1,
#   'chest': 2,
#   'An': 1,
#   'interest': 1,
#   'bedroom': 2,
#   'basic': 1,
#   'function': 1,
#   'group': 2,
#   'dresser': 2,
#   'corner': 1,
#   'unit': 1,
#   'cant': 1,
#   'headboard': 1,
#   'heavier': 1,
#   'style': 1,
#   'door-front': 1,
#   'poster': 1,
#   'bed': 2,
#   'mirror': 1,
#   'bright': 1,
#   'eastman': 1,
#   'chromspun': 1,
#   'fabric': 4,
#   'magenta': 1,
#   'tone': 2,
#   'predomin': 1,
#   'well': 2,
#   'shade': 1,
#   'scotchgard': 1,
#   'finish': 2,
#   'resist': 1,
#   'soil': 1,
#   'element': 1,
#   'close': 1,
#   'root': 1,
#   'tradit': 1,
#   'form': 1,
#   'wear': 2,
#   'definit': 1,
#   'label': 1,
#   'keynot': 2,
#   "drexel'": 1,
#   'fall': 1,
#   'spider-leg': 1,
#   'pedest': 1,
#   'base': 1,
#   'set': 1,
#   'lustrou': 1,
#   'see-through': 1,
#   'chair': 1,
#   'nostalg': 1,
#   'ladder': 1,
#   'shoji': 1,
#   'area': 1,
#   'orang': 1,
#   'manner': 1,
#   'reflect': 1,
#   'best': 1,
#   'aspect': 1,
#   'substanc': 1,
#   'hand-screen': 1,
#   'actual': 1,
#   'tall': 2,
#   'bookcas': 1,
#   'mellow': 1,
#   'bronzy-green-gold': 1,
#   'gleam': 1,
#   'copper': 1,
#   'hand-craft': 1,
#   'accessori': 1,
#   'reiter': 1,
#   'mood': 1,
#   'alexand': 1,
#   'smith': 1,
#   'carpet': 1,
#   'wool': 1,
#   'loop': 1,
#   'pile': 1,
#   'vagabond': 1,
#   'road': 1,
#   'way': 1,
#   'saledo': 3,
#   'coach': 2,
#   'air-condit': 1,
#   'car': 1,
#   'thi': 1,
#   'weekend': 2,
#   'reserv': 1,
#   'entir': 1,
#   'stagecoach': 3,
#   'inn': 1,
#   'adjoin': 1,
#   'countri': 2,
#   'festiv': 1,
#   'invit': 1,
#   'extend': 1,
#   'austin': 1,
#   'dignitari': 1,
#   'gov.': 1,
#   'price': 1,
#   'daniel': 1,
#   'theme': 1,
#   'chisholm': 2,
#   'trail': 2,
#   'get-togeth': 1,
#   'friday': 1,
#   'banquet': 1,
#   'patio': 1,
#   'pool': 1,
#   'play': 1,
#   'costum': 1,
#   'typic': 1,
#   'gingham': 1,
#   'calico': 1,
#   'popular': 1,
#   'men': 2,
#   'western': 1,
#   'attir': 1,
#   'stetson': 1,
#   'vest': 1,
#   'yellow': 1,
#   'bush': 1,
#   'bluebonnet': 1,
#   'there': 1,
#   'draw': 1,
#   'sunbonnet': 1,
#   'flash': 1,
#   'phil': 1,
#   'abel': 1,
#   'chairmen': 2,
#   'trip': 1,
#   'committe': 1,
#   'aid': 1,
#   'plan': 1,
#   'entertain': 1,
#   'messr': 1,
#   'mme': 3,
#   'roy': 1,
#   'mckee': 2,
#   'georg': 1,
#   'mcelye': 1,
#   'jack': 1,
#   'fan': 1,
#   'W.': 2,
#   'H.': 2,
#   'roquemor': 2,
#   'joe': 1,
#   'darrow': 1,
#   'travel': 1,
#   'compris': 1,
#   '75': 1,
#   'fun-lov': 1,
#   'coupl': 1,
#   'motto': 1,
#   'Go': 1,
#   'somewher': 1,
#   'anywher': 1,
#   'everywher': 1,
#   'their': 1,
#   'climax': 1,
#   'spring': 1,
#   '1962': 1,
#   'europ': 1,
#   'past': 1,
#   'charter': 1,
#   'plane': 1,
#   'la': 1,
#   'vega': 1,
#   'jamaica': 1,
#   'buse': 1,
#   'miner': 1,
#   'kerrvil': 1,
#   'railway': 1,
#   'shreveport': 1,
#   'galveston': 1,
#   'parti': 1,
#   'given': 1,
#   'year': 1,
#   'near': 1,
#   'away': 1,
#   'vicin': 1,
#   "club'": 1,
#   'R.': 1,
#   'P.': 1,
#   'anderson': 1,
#   'A.': 1,
#   'schmalzri': 1,
#   'secretari': 1,
#   'treasur': 1,
#   'follow': 1,
#   'lawrenc': 1,
#   'jone': 1,
#   'yearbook': 1,
#   'sam': 1,
#   'laughlin': 1,
#   'scrapbook': 1},
#  'ca30': {'A': 6,
#   'cooki': 3,
#   'caramel': 1,
#   'fill': 2,
#   'chocol': 1,
#   'frost': 1,
#   '$25,000': 1,
#   'minneapoli': 1,
#   'housewif': 1,
#   '13th': 1,
#   'annual': 3,
#   'pillsburi': 1,
#   'bake-off': 3,
#   'tuesday': 1,
#   'mrs.': 13,
#   'alic': 2,
#   'H.': 2,
#   'rees': 3,
#   'wife': 6,
#   'engin': 1,
#   'mother': 3,
#   '23-year-old': 1,
#   'son': 3,
#   'award': 1,
#   'top': 2,
#   'prize': 2,
#   'luncheon': 1,
#   'beverli': 5,
#   'hilton': 2,
#   'hotel': 2,
#   'enter': 2,
#   '10': 1,
#   'past': 3,
#   'got': 4,
#   'final': 2,
#   'second': 2,
#   'grand': 1,
#   '$5,000': 1,
#   'went': 2,
#   'clara': 1,
#   'L.': 2,
#   'oliv': 2,
#   'hawaiian': 1,
#   'coffe': 1,
#   'ring': 1,
#   'rich': 1,
#   'yeast': 1,
#   'bread': 1,
#   'coconut': 1,
#   'vanilla': 1,
#   'glaze': 1,
#   'five': 2,
#   'children': 3,
#   'machinist': 1,
#   'she': 5,
#   'live': 4,
#   'wellsvil': 1,
#   'mo.': 1,
#   'bake': 2,
#   'third': 3,
#   'time': 3,
#   'and': 3,
#   'charm': 2,
#   'dream': 2,
#   'recip': 1,
#   'tri': 2,
#   'like': 4,
#   'contest': 1,
#   'the': 7,
#   'photograph': 1,
#   'told': 1,
#   'finalist': 1,
#   'floor': 1,
#   'ballroom': 1,
#   'critic': 1,
#   'eye': 1,
#   'tongu': 1,
#   'judg': 2,
#   'mr.': 7,
#   'joseph': 2,
#   'R.': 1,
#   'bolker': 2,
#   'give': 2,
#   'dinner': 1,
#   'friday': 1,
#   'home': 2,
#   'hill': 6,
#   'honor': 2,
#   'norman': 1,
#   'chandler': 3,
#   'chairman': 1,
#   'music': 1,
#   'center': 3,
#   'build': 2,
#   'fund': 2,
#   'committe': 1,
#   'head': 2,
#   'group': 1,
#   'within': 1,
#   'develop': 2,
#   'industri': 1,
#   'rais': 1,
#   'support': 1,
#   'cultur': 1,
#   'perform': 1,
#   'art': 3,
#   'featur': 1,
#   'parti': 3,
#   'present': 1,
#   'welton': 1,
#   'becket': 1,
#   'architect': 1,
#   'color': 1,
#   'slide': 1,
#   'render': 1,
#   'three-build': 1,
#   'complex': 2,
#   'foliag': 2,
#   'glow': 1,
#   'formal': 2,
#   'fall': 2,
#   'flower': 3,
#   'decor': 4,
#   'lo': 4,
#   'angel': 4,
#   'countri': 4,
#   'club': 3,
#   'saturday': 1,
#   'even': 4,
#   'more': 2,
#   '200': 1,
#   'expect': 1,
#   'autumn': 1,
#   'event': 1,
#   'match': 1,
#   'spring': 1,
#   'among': 1,
#   'reserv': 1,
#   'messrs.': 1,
#   'mmes.': 2,
#   'william': 3,
#   'A.': 3,
#   'thompson': 1,
#   'van': 1,
#   'cott': 1,
#   'niven': 1,
#   'B.': 2,
#   'cox': 1,
#   'david': 2,
#   'bricker': 1,
#   'samuel': 2,
#   'perri': 1,
#   'robert': 3,
#   'D.': 1,
#   'stetson': 1,
#   'other': 3,
#   'drs.': 1,
#   'alfr': 1,
#   'robbin': 1,
#   'J.': 1,
#   'lafe': 1,
#   'ludwig': 1,
#   'gen.': 1,
#   'leroy': 1,
#   'watson': 1,
#   'guest': 3,
#   'across': 1,
#   'u.s.': 1,
#   'dr.': 5,
#   'swim': 3,
#   'when': 2,
#   'W.': 1,
#   'celebr': 1,
#   '75th': 1,
#   'birthday': 1,
#   'wilshir': 2,
#   'came': 2,
#   'charter': 1,
#   'plane': 2,
#   'flight': 1,
#   'origin': 1,
#   'florida': 1,
#   'pick': 1,
#   'east': 1,
#   'coast': 2,
#   'midwest': 1,
#   'left': 1,
#   'seattl': 1,
#   'take': 8,
#   'passeng': 1,
#   'west': 1,
#   'point': 1,
#   'cocktail': 1,
#   'buffet': 1,
#   'supper': 1,
#   'serv': 2,
#   '100': 1,
#   'person': 1,
#   'known': 1,
#   'practic': 4,
#   'He': 1,
#   'start': 1,
#   '1917': 1,
#   'state': 1,
#   'board': 1,
#   'medic': 1,
#   'examin': 1,
#   'violin': 2,
#   'open': 1,
#   'whole': 2,
#   'new': 8,
#   'career': 2,
#   'ilona': 1,
#   'schmidl-seeberg': 1,
#   'tini': 1,
#   'hungarian': 2,
#   'fritz': 1,
#   'kreisler': 1,
#   'predict': 1,
#   'would': 3,
#   'promis': 1,
#   'concert': 1,
#   'stage': 1,
#   'heart': 1,
#   'attack': 1,
#   'bare': 2,
#   '20': 1,
#   'put': 3,
#   'end': 2,
#   '10-hour': 1,
#   'daili': 2,
#   'away': 4,
#   'took': 1,
#   'linen': 1,
#   'needl': 1,
#   'yarn': 1,
#   'long': 3,
#   'idl': 1,
#   'day': 4,
#   'budapest': 2,
#   'now': 2,
#   'modern': 1,
#   'tapestri': 2,
#   'exhibit': 1,
#   'two': 6,
#   'contin': 1,
#   '26': 1,
#   'feel': 4,
#   'threshold': 1,
#   'life': 1,
#   'her': 1,
#   'student': 1,
#   'univers': 2,
#   'sudden': 1,
#   'upris': 1,
#   '1957': 1,
#   'husband': 1,
#   'stephen': 1,
#   'fled': 1,
#   'vienna': 1,
#   'there': 2,
#   'continu': 1,
#   'studi': 1,
#   'architectur': 1,
#   'first': 1,
#   'show': 2,
#   'work': 4,
#   "there'": 1,
#   'lot': 1,
#   'talk': 1,
#   'problem': 4,
#   'educ': 2,
#   'america': 1,
#   'today': 1,
#   'what': 1,
#   'peopl': 2,
#   'seem': 2,
#   'realiz': 1,
#   'tie': 2,
#   'thing': 1,
#   'I': 16,
#   '90%': 1,
#   'transport': 1,
#   'never': 1,
#   'logist': 1,
#   'difficulti': 1,
#   'involv': 1,
#   'last': 4,
#   'boy': 1,
#   'squeez': 1,
#   'high': 2,
#   'school': 9,
#   'It': 1,
#   'year': 2,
#   'watch': 1,
#   'set': 1,
#   'hand': 2,
#   'raini': 1,
#   'yellow': 1,
#   'raincoat': 1,
#   'finger-paint': 1,
#   'grammar': 1,
#   'get': 4,
#   'they': 3,
#   'either': 1,
#   'walk': 7,
#   'driven': 7,
#   'go': 3,
#   'mile': 3,
#   'one': 4,
#   'might': 1,
#   'think': 1,
#   'similar': 1,
#   'could': 5,
#   'ride': 5,
#   'bu': 3,
#   "it'": 1,
#   'much': 1,
#   'gener': 3,
#   'girl': 4,
#   'name': 2,
#   'gloriana': 3,
#   'block': 1,
#   'car': 13,
#   'thi': 2,
#   'way': 3,
#   'understand': 1,
#   'entail': 1,
#   'certain': 2,
#   'loss': 2,
#   'social': 3,
#   'statu': 2,
#   'young': 2,
#   'man': 1,
#   'front': 2,
#   'higher': 1,
#   'class': 1,
#   'also': 3,
#   '``': 11,
#   'whi': 1,
#   "''": 11,
#   'suggest': 1,
#   'My': 2,
#   'father': 1,
#   'snow': 1,
#   'illinoi': 2,
#   'did': 1,
#   'ask': 1,
#   'No': 1,
#   'said': 1,
#   'happen': 1,
#   'grow': 1,
#   'explain': 1,
#   'howev': 3,
#   'share': 1,
#   'hardship': 1,
#   'make': 2,
#   'pilgrimag': 1,
#   'feet': 2,
#   'wisdom': 1,
#   'streetcar': 2,
#   'sometim': 3,
#   'late': 1,
#   'seat': 1,
#   'stand': 1,
#   'ladi': 1,
#   'wrong': 1,
#   'wound': 1,
#   'ocean': 1,
#   'dismal': 1,
#   'place': 1,
#   'spend': 1,
#   "i'v": 1,
#   'compromis': 1,
#   'let': 1,
#   'littl': 3,
#   'drive': 3,
#   'big': 4,
#   'least': 1,
#   'woman': 1,
#   'satisfactori': 1,
#   'If': 2,
#   "they'd": 1,
#   'rather': 2,
#   'say': 2,
#   'but': 3,
#   'usual': 2,
#   'enough': 1,
#   'logic': 1,
#   'impecc': 1,
#   'cours': 1,
#   'except': 1,
#   'fool': 1,
#   'everybodi': 1,
#   'know': 1,
#   'capabl': 1,
#   'solut': 1,
#   'natur': 1,
#   'half-mil': 1,
#   'steep': 1,
#   'hous': 1,
#   'hard': 2,
#   'leg': 2,
#   'us': 1,
#   "that'": 1,
#   'hardli': 1,
#   'realist': 1,
#   'nobodi': 1,
#   'anymor': 1,
#   'crackpot': 1,
#   'harri': 1,
#   'truman': 1,
#   "he'": 1,
#   'alreadi': 1,
#   'advanc': 1,
#   'public': 1,
#   'blue': 2,
#   'book': 5,
#   'mention': 1,
#   'drop': 1,
#   'notic': 1,
#   'york': 2,
#   'regist': 2,
#   'made': 1,
#   'news': 1,
#   'week': 1,
#   'publish': 2,
#   'hord': 1,
#   'richardson': 2,
#   '1962': 1,
#   'edit': 1,
#   'subtitl': 1,
#   'societi': 1,
#   'southern': 3,
#   'california': 3,
#   'schedul': 1,
#   'arriv': 1,
#   'monday': 1,
#   "morning'": 1,
#   'postman': 1,
#   'updat': 1,
#   'still': 1,
#   'remain': 1,
#   'compact': 1,
#   'refer': 1,
#   'use': 4,
#   'mani': 2,
#   'ever-chang': 1,
#   'telephon': 1,
#   'number': 2,
#   'address': 5,
#   'resid': 3,
#   'affili': 1,
#   'marriag': 6,
#   'star': 2,
#   'throughout': 1,
#   'volum': 1,
#   'denot': 1,
#   'date': 1,
#   'ad': 1,
#   'press': 1,
#   'meredith': 1,
#   'jane': 2,
#   'cooper': 2,
#   'daughter': 5,
#   'grant': 1,
#   'knox': 1,
#   'worrel': 1,
#   'mari': 1,
#   'ghormley': 1,
#   'willard': 1,
#   'pen': 1,
#   'tudor': 1,
#   'carla': 1,
#   'ruth': 1,
#   'craig': 1,
#   'dan': 1,
#   'mcfarland': 1,
#   'jr.': 5,
#   'joann': 1,
#   'curri': 2,
#   'ellsworth': 1,
#   'jame': 2,
#   'hartley': 1,
#   'gregg': 1,
#   'valeri': 1,
#   'smith': 2,
#   'mcalist': 1,
#   'duqu': 1,
#   'note': 4,
#   'elizabeth': 1,
#   'brown': 2,
#   'georg': 1,
#   'austin': 1,
#   'C.': 1,
#   'cynthia': 1,
#   'ludlow': 1,
#   'todd': 1,
#   'huntington': 2,
#   'pasadena': 3,
#   'list': 4,
#   'newli': 1,
#   'wed': 1,
#   'section': 1,
#   'moodi': 1,
#   'haskin': 1,
#   '3': 1,
#   'former': 1,
#   'judi': 1,
#   'chapman': 2,
#   'john': 3,
#   'S.': 2,
#   'citi': 2,
#   'coupl': 1,
#   'anoth': 1,
#   'mcalest': 1,
#   'loui': 1,
#   'pfau': 1,
#   'chang': 3,
#   'for': 1,
#   'instanc': 1,
#   'edwin': 1,
#   'pauley': 1,
#   'formerli': 5,
#   'chantilli': 1,
#   'rd.': 1,
#   'north': 1,
#   'arden': 2,
#   'moulton': 2,
#   'franklin': 1,
#   'windsor': 1,
#   'blvd.': 2,
#   'richard': 2,
#   'beesemy': 1,
#   'connecticut': 1,
#   'return': 1,
#   'south': 1,
#   'raoul': 1,
#   'esnard': 1,
#   'exchang': 1,
#   'mexico': 1,
#   'julian': 1,
#   'hazard': 1,
#   'laguna': 1,
#   'beach': 1,
#   'frank': 1,
#   'wangeman': 1,
#   'move': 1,
#   'manag': 1,
#   'waldorf-astoria': 1,
#   'lawrenc': 1,
#   'chase': 3,
#   'ransom': 1,
#   'oxford': 1,
#   'eng.': 1,
#   'T.': 1,
#   'olerich': 1,
#   'aderhold': 1,
#   'henri': 1,
#   'De': 1,
#   'La': 1,
#   'chapel': 1,
#   'bertero': 1,
#   'egerton': 1,
#   'crispin': 1,
#   'armistead': 1,
#   'allen': 1,
#   'howard': 1,
#   'locki': 2,
#   'thoma': 1,
#   'anthoni': 1,
#   'longinotti': 1,
#   'newcom': 1,
#   'part': 1,
#   'ray': 1,
#   'carbon': 1,
#   'panama': 1,
#   'gedd': 1,
#   'macgregor': 1,
#   'scotland': 1,
#   'werner': 1,
#   'althau': 1,
#   'switzerland': 1,
#   "here'": 1,
#   'idea': 1,
#   "child'": 3,
#   'room': 1,
#   'easi': 1,
#   'execut': 1,
#   'complet': 1,
#   'puppet': 9,
#   'lamp': 5,
#   'base': 2,
#   'most': 1,
#   'love': 1,
#   'anim': 1,
#   'face': 1,
#   'flexibl': 1,
#   'bodi': 1,
#   'prefer': 1,
#   'see': 1,
#   'though': 1,
#   'action': 1,
#   'box': 1,
#   'display': 1,
#   'delight': 1,
#   'accent': 1,
#   'To': 1,
#   'creat': 2,
#   'order': 1,
#   'wire': 2,
#   'pedest': 2,
#   'shop': 1,
#   'measur': 1,
#   'determin': 1,
#   'height': 1,
#   'light': 3,
#   'socket': 1,
#   'allow': 1,
#   'three': 2,
#   'four': 1,
#   'inch': 2,
#   "puppet'": 1,
#   'sure': 1,
#   'metal': 1,
#   'tube': 1,
#   'pass': 1,
#   'shape': 1,
#   'invert': 1,
#   'L': 2,
#   'foot': 2,
#   'hang': 1,
#   'directli': 1,
#   'pull': 1,
#   'string': 3,
#   'manipul': 1,
#   'suspend': 1,
#   'fixtur': 1,
#   'In': 2,
#   'arrang': 1,
#   'arm': 1,
#   'desir': 1,
#   'posit': 1,
#   'rest': 1,
#   'uniform': 1,
#   'size': 1,
#   'accord': 2,
#   'whim': 1,
#   'although': 1,
#   'straight': 1,
#   'drum': 1,
#   'shade': 2,
#   'adequ': 1,
#   'suffici': 1,
#   'neutral': 1,
#   'without': 1,
#   'disharmoni': 1,
#   'far': 1,
#   'fun': 1,
#   'gay': 1,
#   'spirit': 1,
#   'playtim': 1,
#   'those': 1,
#   'illustr': 1,
#   'reminisc': 1,
#   'circu': 1,
#   'merry-go-round': 1,
#   'scallop': 1,
#   'edg': 1,
#   'particularli': 1,
#   'appeal': 1,
#   "today'": 1,
#   'trend': 1,
#   'toward': 1,
#   'furnitur': 1,
#   'design': 4,
#   "america'": 1,
#   'teach': 1,
#   'home-own': 1,
#   'renew': 1,
#   'respect': 1,
#   'shrewd': 1,
#   'cabinetmak': 1,
#   'coloni': 2,
#   'era': 1,
#   'ago': 1,
#   'plenti': 1,
#   'appreci': 1,
#   'antiqu': 1,
#   'fine': 2,
#   'reproduct': 1,
#   'background': 1,
#   'lurk': 1,
#   'piec': 2,
#   'beauti': 1,
#   'lack': 1,
#   'utilitarian': 1,
#   'touch': 1,
#   'So': 1,
#   "junior'": 1,
#   'bedroom': 1,
#   'trick': 1,
#   'heavi': 1,
#   'nondescript': 1,
#   'supposedli': 1,
#   'knock': 1,
#   'secretari': 1,
#   'releg': 1,
#   'parlor': 1,
#   'true': 1,
#   'homemak': 1,
#   "1960'": 1,
#   'consult': 1,
#   'leland': 1,
#   'alden': 2,
#   'housew': 1,
#   'find': 1,
#   'liter': 1,
#   'hundr': 1,
#   'maximum': 1,
#   'tradit': 1,
#   'larg': 1,
#   'craftsmen': 1,
#   'innat': 1,
#   'sens': 1,
#   'solid': 1,
#   'invest': 1,
#   'reason': 1,
#   'eighteenth': 1,
#   'centuri': 1,
#   'earth': 1,
#   '--': 1,
#   'busi': 1}}

# %%
# Calculating TF - Term Frecquency
# indexes of non zero values
tf_matrix = []
nonzeros = []

# %%
for fileid in fileids:
    tf_vector = [0] * words_count
    nonzeros_vec = []
    for word in frequencies[fileid].keys():
        f = frequencies[fileid][word]
        tf_vector[dictionary[word]] = f
        if f > 0:
            nonzeros_vec.append(dictionary[word])
    nonzeros.append(nonzeros_vec)
    tf_matrix.append(tf_vector)

# %%
len(tf_matrix)
# Out:
# 30

# %%
len(tf_matrix[0])
# Out:
# 7823

# %%
len(tf_matrix[1])
# Out:
# 7823

# %%
# Calculating IDF - Inverse Document Frequency
idf_matrix = [0] * words_count
for fileid in fileids:
    for word in frequencies[fileid].keys():
        idf_matrix[dictionary[word]] += 1

# %%
# Calculating TF-IDF matrix
tfidf = []

for i in range(documents_count):
    vector = [0] * words_count
    for j in nonzeros[i]:
        tf_value = tf_matrix[i][j]
        idf_value = idf_matrix[j]
        tf_value = 1 + log(tf_value, 2)
        idf_value = log(1 + documents_count/ float(idf_value), 2)
        vector[j] = tf_value * idf_value
    tfidf.append(vector)

# %%
type(tfidf)
# Out:
# list

# %%
print("------ Top 10 : Keywords per document -------")
for i in range(len(tfidf)):
    print("--- Document  : " + str(fileids[i]))
    vector = tfidf[i]
    sorted = np.argsort(vector)[::-1]
    for ind in sorted[:15]:
        stem = list(dictionary.keys())[list(dictionary.values()).index(ind)]
        beforeStemming = list(filtered.keys())[list(filtered.values()).index(stem)]
        print(beforeStemming  + "  -- " + str(vector[ind]))
# Out:
# ------ Top 10 : Keywords per document -------
# --- Document  : ca01
# Fulton  -- 23.816580017577966
# Hartsfield  -- 16.457483911061473
# Pelham  -- 16.457483911061473
# Vandiver  -- 14.862588931160627
# resolution  -- 14.425570397335713
# Atlanta  -- 13.287712379549449
# irregularities  -- 12.806411683561183
# Highway  -- 12.349851365001358
# Georgia's  -- 12.0
# Georgia  -- 12.0
# Jury  -- 11.796960646027419
# petition  -- 11.068438508252463
# rural  -- 11.068438508252463
# anonymous  -- 10.339850002884624
# campaign  -- 10.256329554270263
# --- Document  : ca02
# ADC  -- 19.816785241547503
# Clark  -- 17.76060799394806
# deaf  -- 17.76060799394806
# Parkhouse  -- 16.457483911061473
# Cotten  -- 14.862588931160627
# Rep.  -- 14.339850002884624
# Dallas  -- 13.195802578558453
# Ratcliff  -- 12.806411683561183
# semester  -- 12.806411683561183
# Texas  -- 12.121538695885583
# Daniel  -- 12.0
# Grover  -- 12.0
# Sen.  -- 10.688596580458661
# discrimination  -- 10.339850002884624
# Oklahoma  -- 10.339850002884624
# --- Document  : ca03
# Karns  -- 18.862383707191093
# Wexler  -- 17.76060799394806
# dental  -- 17.76060799394806
# Bellows  -- 16.457483911061473
# precincts  -- 16.0
# message  -- 14.862588931160627
# 23d  -- 14.862588931160627
# Nursing  -- 13.171284000740421
# care  -- 12.87161704384908
# Parsons  -- 12.806411683561183
# medicine  -- 12.806411683561183
# medical  -- 12.426832201176182
# payroll  -- 12.401932626623804
# patient  -- 12.0
# Criminal  -- 12.0
# --- Document  : ca04
# NATO  -- 18.862383707191093
# Laos  -- 17.59972981166377
# Oslo  -- 16.457483911061473
# Cuba  -- 14.862588931160627
# Communists  -- 14.512432967297842
# juvenile  -- 13.287712379549449
# alliance  -- 12.806411683561183
# delinquency  -- 12.806411683561183
# Rusk's  -- 12.806411683561183
# Nixon  -- 12.806411683561183
# policies  -- 12.426832201176182
# allies  -- 12.0
# correspondents  -- 10.339850002884624
# Geneva  -- 10.339850002884624
# diplomat  -- 10.339850002884624
# --- Document  : ca05
# Hawksley  -- 21.41168022144835
# CD  -- 18.862383707191093
# Martinelli  -- 18.862383707191093
# full-time  -- 17.76060799394806
# Socialist  -- 17.76060799394806
# Reama  -- 16.457483911061473
# town  -- 12.874488492753906
# Bourcier  -- 12.806411683561183
# charter  -- 12.519207304160728
# civil  -- 12.401932626623804
# Johnston  -- 12.0
# Notte  -- 12.0
# council  -- 11.239637567217928
# signatures  -- 10.378294855911893
# resolution  -- 10.378294855911893
# --- Document  : ca06
# warden  -- 16.457483911061473
# Sandman  -- 16.457483911061473
# Mitchell  -- 16.260849782435884
# Westfield  -- 14.862588931160627
# campaign  -- 14.155901349502802
# Eisenhower  -- 13.837726474549191
# gubernatorial  -- 13.287712379549449
# Republicans  -- 13.114092193912846
# Trenton  -- 12.806411683561183
# carcass  -- 12.806411683561183
# Sheeran  -- 12.806411683561183
# Meyner  -- 12.806411683561183
# Hughes  -- 12.519207304160728
# Jersey  -- 12.401932626623804
# sheet  -- 12.0
# --- Document  : ca07
# Buckley  -- 17.76060799394806
# Bronx  -- 16.457483911061473
# Prince  -- 13.287712379549449
# Screvane  -- 12.806411683561183
# politicians  -- 12.806411683561183
# corruption  -- 12.806411683561183
# Wagner  -- 12.401932626623804
# Democratic  -- 12.01049221785673
# Beame  -- 12.0
# religious  -- 11.491983086292903
# coalition  -- 11.491983086292903
# Mayor  -- 11.17202205609706
# mates  -- 10.378294855911893
# interviews  -- 10.378294855911893
# Premier  -- 10.339850002884624
# --- Document  : ca08
# Barnett  -- 17.28771237954945
# Pfaff  -- 14.862588931160627
# $28  -- 14.862588931160627
# Pennsylvania  -- 13.287712379549449
# Legislature  -- 12.87161704384908
# Mississippi  -- 12.0
# segregation  -- 12.0
# Davis  -- 10.688596580458661
# historic  -- 10.378294855911893
# parade  -- 10.378294855911893
# transition  -- 10.339850002884624
# division  -- 10.064262121791474
# weary  -- 9.908392620773752
# token  -- 9.908392620773752
# commercial  -- 9.908392620773752
# --- Document  : ca09
# Hemphill  -- 19.816785241547503
# Berger  -- 16.457483911061473
# Eastwick  -- 16.457483911061473
# dog  -- 15.229419688230417
# Fighters  -- 14.862588931160627
# Goodis  -- 14.862588931160627
# redevelopers  -- 14.862588931160627
# fees  -- 14.842529686554775
# Barnard  -- 12.806411683561183
# esplanade  -- 12.806411683561183
# rigged  -- 12.806411683561183
# Gursel  -- 12.806411683561183
# Gladden  -- 12.806411683561183
# PTC  -- 12.806411683561183
# junta  -- 12.806411683561183
# --- Document  : ca10
# beliefs  -- 17.76060799394806
# God  -- 16.0
# Zimmerman  -- 12.806411683561183
# Molvar  -- 12.806411683561183
# Bible  -- 12.806411683561183
# Ierulli  -- 12.806411683561183
# Rev.  -- 12.401932626623804
# Portland  -- 11.491983086292903
# Powell  -- 10.339850002884624
# Brandt  -- 10.339850002884624
# Salem  -- 10.339850002884624
# church  -- 10.169849813664454
# Weinstein  -- 9.908392620773752
# Schwab  -- 9.908392620773752
# Hatfield  -- 9.908392620773752
# --- Document  : ca11
# Orioles  -- 22.092899671475475
# Hansen  -- 19.816785241547503
# Hyde  -- 14.862588931160627
# Lumpe  -- 14.862588931160627
# Throneberry  -- 14.862588931160627
# Hartman  -- 14.862588931160627
# A's  -- 14.862588931160627
# Kansas  -- 14.339850002884624
# Robinson  -- 12.874488492753906
# Kerr  -- 12.806411683561183
# Keegan  -- 12.806411683561183
# Flock  -- 12.806411683561183
# Siebern  -- 12.806411683561183
# Shortstop  -- 12.806411683561183
# Gentile  -- 12.806411683561183
# --- Document  : ca12
# Moritz  -- 22.092899671475475
# Meek  -- 20.65862705673549
# halfback  -- 20.65862705673549
# Rice  -- 18.862383707191093
# yards  -- 18.15484637232335
# kick  -- 17.837726474549193
# Longhorn  -- 17.76060799394806
# place-kicker  -- 14.862588931160627
# Gannon  -- 14.862588931160627
# Stram  -- 14.862588931160627
# M  -- 14.862588931160627
# game  -- 14.7354229090162
# Texans  -- 14.339850002884624
# sophomore  -- 12.806411683561183
# fullback  -- 12.806411683561183
# --- Document  : ca13
# Liston  -- 17.76060799394806
# inning  -- 15.229419688230417
# infield  -- 14.862588931160627
# Jensen  -- 14.862588931160627
# Gardner's  -- 14.862588931160627
# Sox  -- 14.339850002884624
# Jay  -- 12.806411683561183
# Nischwitz  -- 12.806411683561183
# Ogden  -- 12.806411683561183
# Rudolph  -- 12.806411683561183
# Lemon  -- 12.806411683561183
# rightfield  -- 12.806411683561183
# game  -- 12.426832201176182
# bearing  -- 12.349851365001358
# batting  -- 11.491983086292903
# --- Document  : ca14
# Skorich  -- 21.41168022144835
# Shea  -- 20.65862705673549
# Palmer  -- 18.862383707191093
# Arnold  -- 16.67970000576925
# Eagles  -- 16.457483911061473
# Vikings  -- 12.806411683561183
# duffer  -- 12.806411683561183
# provisional  -- 12.806411683561183
# Golfers  -- 12.806411683561183
# coach  -- 11.229419688230417
# Yankees  -- 11.068438508252463
# strokes  -- 10.339850002884624
# hero  -- 10.339850002884624
# Pittsburgh  -- 10.339850002884624
# golf  -- 10.256329554270263
# --- Document  : ca15
# Benington  -- 18.862383707191093
# Mantle  -- 17.28771237954945
# Hartweger  -- 16.457483911061473
# Hemus  -- 16.457483911061473
# Pirates  -- 16.0
# Billikens  -- 14.862588931160627
# Nordmann  -- 14.862588931160627
# Murtaugh  -- 12.806411683561183
# Musial  -- 12.806411683561183
# Mizell  -- 12.806411683561183
# Mankowski  -- 12.806411683561183
# Bradley  -- 12.806411683561183
# Redbirds  -- 12.806411683561183
# Nieman  -- 12.806411683561183
# Cardinals  -- 12.0
# --- Document  : ca16
# Wendell  -- 18.862383707191093
# Monroe  -- 16.457483911061473
# Tarzan  -- 14.862588931160627
# Geraghty  -- 14.862588931160627
# bride's  -- 14.862588931160627
# met  -- 13.171284000740421
# Hamm  -- 12.806411683561183
# Geraghty's  -- 12.806411683561183
# Maureen  -- 12.806411683561183
# Florence  -- 12.806411683561183
# wedding  -- 12.401932626623804
# Burke  -- 10.378294855911893
# Johnny  -- 10.378294855911893
# debut  -- 10.378294855911893
# Italian  -- 10.378294855911893
# --- Document  : ca17
# Marr  -- 17.76060799394806
# bride  -- 15.229419688230417
# motels  -- 14.425570397335713
# La.  -- 13.287712379549449
# Calif.  -- 13.287712379549449
# boasting  -- 12.806411683561183
# Meredith  -- 12.0
# Kelsey  -- 12.0
# pooling  -- 10.378294855911893
# Baker  -- 10.378294855911893
# wedding  -- 10.378294855911893
# Mullenax  -- 9.908392620773752
# neckline  -- 9.908392620773752
# Salvation  -- 9.908392620773752
# alcoholics  -- 9.908392620773752
# --- Document  : ca18
# bundle  -- 19.816785241547503
# Thrift  -- 16.457483911061473
# Philmont  -- 14.862588931160627
# Drexel  -- 13.287712379549449
# Queens  -- 13.287712379549449
# Spurdle  -- 12.806411683561183
# Vieth  -- 12.806411683561183
# Carnival  -- 12.806411683561183
# Eustis  -- 12.806411683561183
# Jewish  -- 12.806411683561183
# hostesses  -- 12.806411683561183
# entertainment  -- 12.519207304160728
# artist  -- 11.491983086292903
# Orleans  -- 10.378294855911893
# chose  -- 10.339850002884624
# --- Document  : ca19
# Simpkins  -- 18.862383707191093
# Annapolis  -- 17.76060799394806
# Jenkins  -- 16.457483911061473
# Arundel  -- 16.457483911061473
# snow  -- 15.229419688230417
# Schaefer  -- 14.862588931160627
# Councilman  -- 14.862588931160627
# lay-offs  -- 14.862588931160627
# Somerset  -- 12.806411683561183
# Werner  -- 12.0
# employees  -- 12.0
# payroll  -- 10.378294855911893
# reduction  -- 10.339850002884624
# Maryland  -- 10.339850002884624
# storm  -- 10.339850002884624
# --- Document  : ca20
# British  -- 20.65862705673549
# narcotics  -- 19.816785241547503
# Dreadnought  -- 17.76060799394806
# Evanston  -- 17.76060799394806
# submarines  -- 17.28771237954945
# secret  -- 16.630715619377717
# hull  -- 14.862588931160627
# reactor  -- 14.862588931160627
# Skipjack  -- 14.862588931160627
# Kroger  -- 14.862588931160627
# bail  -- 14.862588931160627
# Sokol  -- 14.862588931160627
# Stickney  -- 14.862588931160627
# underwater  -- 13.287712379549449
# indictment  -- 13.287712379549449
# --- Document  : ca21
# Kowalski  -- 25.204289637352765
# Hengesbach  -- 20.65862705673549
# Havana  -- 18.862383707191093
# Pohl  -- 18.862383707191093
# Kimmell  -- 14.862588931160627
# verdict  -- 14.425570397335713
# Laos  -- 13.171284000740421
# McNair  -- 12.806411683561183
# Vicky  -- 12.806411683561183
# Sterling  -- 12.806411683561183
# Township  -- 12.806411683561183
# neighboring  -- 12.349851365001358
# Funeral  -- 10.378294855911893
# Cuban  -- 10.378294855911893
# rebel  -- 10.339850002884624
# --- Document  : ca22
# Emory  -- 23.816580017577966
# Atlanta  -- 16.67970000576925
# COAHR  -- 16.457483911061473
# Georgia  -- 15.229419688230417
# Killingsworth  -- 14.862588931160627
# scratching  -- 14.862588931160627
# Expressway  -- 14.862588931160627
# theater  -- 13.495951502516263
# eradication  -- 12.806411683561183
# Blasingame  -- 12.806411683561183
# desegregation  -- 12.806411683561183
# stand-ins  -- 12.806411683561183
# flames  -- 12.806411683561183
# NW  -- 12.806411683561183
# creed  -- 12.806411683561183
# --- Document  : ca23
# Hillsboro  -- 22.092899671475475
# Portland  -- 17.29715809318649
# Huntley  -- 14.862588931160627
# 4-H  -- 14.862588931160627
# Jossy  -- 14.862588931160627
# Spice-Nice  -- 12.806411683561183
# Brett  -- 12.806411683561183
# robbery  -- 12.0
# ribbon  -- 12.0
# Beaverton  -- 12.0
# Phoenix  -- 12.0
# championship  -- 12.0
# Larson  -- 12.0
# Multnomah  -- 12.0
# Plains  -- 12.0
# --- Document  : ca24
# Cranston  -- 18.862383707191093
# Parrillo  -- 12.806411683561183
# Hester  -- 12.806411683561183
# Vernava  -- 12.806411683561183
# Pezza  -- 12.806411683561183
# NYU  -- 12.806411683561183
# Giorgio  -- 12.806411683561183
# Sorrentino  -- 12.806411683561183
# Parker  -- 12.0
# jurors  -- 11.491983086292903
# accident  -- 10.378294855911893
# pole  -- 10.339850002884624
# Johnston  -- 10.339850002884624
# coins  -- 9.908392620773752
# uninjured  -- 9.908392620773752
# --- Document  : ca25
# Huff  -- 21.41168022144835
# Fiedler  -- 20.65862705673549
# Buchheister  -- 17.76060799394806
# Leavitt  -- 17.76060799394806
# missile  -- 16.67970000576925
# pilots  -- 16.457483911061473
# stein  -- 15.861364245261102
# Gregorio  -- 14.862588931160627
# bomber  -- 14.862588931160627
# weapons  -- 14.862588931160627
# Glimco  -- 14.862588931160627
# Stein's  -- 14.862588931160627
# spraying  -- 14.862588931160627
# Av.  -- 13.287712379549449
# Arger  -- 12.806411683561183
# --- Document  : ca26
# gin  -- 27.669000614721813
# Cotton  -- 18.80175887256437
# Dallas  -- 15.32656222621833
# cleaners  -- 14.862588931160627
# machinery  -- 14.425570397335713
# chip  -- 14.339850002884624
# Morton  -- 13.343792395520603
# Gordin  -- 12.806411683561183
# Ronnie  -- 12.806411683561183
# maker  -- 12.806411683561183
# driers  -- 12.806411683561183
# stocks  -- 12.121538695885583
# quarters  -- 12.0
# potato  -- 11.491983086292903
# share  -- 11.239637567217928
# --- Document  : ca27
# debentures  -- 17.76060799394806
# Peterson  -- 14.862588931160627
# recovery  -- 13.171284000740421
# Diversified  -- 12.806411683561183
# short-term  -- 12.806411683561183
# shareholders  -- 12.806411683561183
# O  -- 12.806411683561183
# B  -- 12.806411683561183
# Sprinkel  -- 12.806411683561183
# Perlman  -- 12.806411683561183
# 1986  -- 12.806411683561183
# Draper  -- 12.806411683561183
# economy  -- 12.401932626623804
# Builders  -- 11.491983086292903
# converted  -- 11.491983086292903
# --- Document  : ca28
# dealers  -- 17.837726474549193
# billion  -- 15.427098742664773
# deductible  -- 15.229419688230417
# 5%  -- 14.862588931160627
# pickers  -- 14.862588931160627
# farms  -- 14.732795135467372
# farmer  -- 13.837726474549191
# income  -- 13.195802578558453
# machinery  -- 13.171284000740421
# 50%  -- 12.806411683561183
# materials  -- 12.806411683561183
# depletion  -- 12.806411683561183
# August  -- 12.349851365001358
# sales  -- 12.174333399641542
# company's  -- 12.0
# --- Document  : ca29
# Greer  -- 16.457483911061473
# Chicken  -- 16.457483911061473
# breast  -- 16.457483911061473
# Contemporary  -- 16.457483911061473
# Garson  -- 16.0
# Ramsey  -- 15.229419688230417
# fabrics  -- 14.862588931160627
# acacia  -- 12.806411683561183
# ebony  -- 12.806411683561183
# Mmes  -- 12.806411683561183
# Stagecoach  -- 12.806411683561183
# Saledo  -- 12.806411683561183
# arches  -- 12.806411683561183
# warmth  -- 12.806411683561183
# Neiman-Marcus  -- 12.806411683561183
# --- Document  : ca30
# puppets  -- 20.65862705673549
# lamp  -- 16.457483911061473
# driven  -- 13.171284000740421
# Gloriana  -- 12.806411683561183
# Pasadena  -- 12.806411683561183
# child's  -- 12.806411683561183
# Chandler  -- 12.806411683561183
# Bake-Off  -- 12.806411683561183
# Reese  -- 12.806411683561183
# Beverly  -- 11.491983086292903
# marriage  -- 11.068438508252463
# cookies  -- 10.339850002884624
# dreamed  -- 9.908392620773752
# Lockies  -- 9.908392620773752
# Hilton  -- 9.908392620773752
