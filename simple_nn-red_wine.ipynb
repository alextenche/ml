# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam

from sklearn.preprocessing import StandardScaler

SEED = 42
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
data = pd.read_csv('data/winequality-red.csv', sep=';')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
y = data['quality']
X = data.drop(['quality'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)

# %%
print('Average quality training set: {:.4f}'.format(y_train.mean()))
X_train.head()
# Out:
# Average quality training set: 5.6239
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 493            8.7             0.690         0.31             3.0      0.086
# 354            6.1             0.210         0.40             1.4      0.066
# 342           10.9             0.390         0.47             1.8      0.118
# 834            8.8             0.685         0.26             1.6      0.088
# 705            8.4             1.035         0.15             6.0      0.073
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 493                 23.0                  81.0  1.00020  3.48       0.74
# 354                 40.5                 165.0  0.99120  3.25       0.59
# 342                  6.0                  14.0  0.99820  3.30       0.75
# 834                 16.0                  23.0  0.99694  3.32       0.47
# 705                 11.0                  54.0  0.99900  3.37       0.49
#
#      alcohol
# 493     11.6
# 354     11.9
# 342      9.8
# 834      9.4
# 705      9.9

# %%
scaler = StandardScaler().fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train))
X_test = pd.DataFrame(scaler.transform(X_test))

# %%
# Predict the mean quality of the training data for each validation input
print('MSE:', np.mean((y_test - ([y_train.mean()] * y_test.shape[0])) ** 2).round(4))
# Out:
# MSE: 0.6572

# %%
model = Sequential()
# First hidden layer with 100 hidden units
model.add(Dense(200, input_dim=X_train.shape[1], activation='relu')) 
# Second hidden layer with 50 hidden units
model.add(Dense(25, activation='relu'))
# Output layer
model.add(Dense(1, activation='linear'))
# Set optimizer
opt = Adam()
# Compile model
model.compile(loss='mse', optimizer=opt, metrics=['accuracy'])

# %%
callbacks = [
             EarlyStopping(monitor='val_acc', patience=20, verbose=2),
             ModelCheckpoint('data/checkpoints/multi_layer_best_model.h5', monitor='val_acc', save_best_only=True, verbose=0)
            ]

# %%
batch_size = 64
n_epochs = 5000

# %%
model.fit(X_train.values, y_train, batch_size=64, epochs=n_epochs, validation_split=0.2,     
             verbose=2,
              validation_data=(X_test.values, y_test),
             callbacks=callbacks)
# Out:
# Train on 1279 samples, validate on 320 samples
# Epoch 1/5000
#  - 1s - loss: 25.5278 - acc: 0.0000e+00 - val_loss: 17.6565 - val_acc: 0.0000e+00
# Epoch 2/5000
#  - 0s - loss: 11.2190 - acc: 0.0156 - val_loss: 5.6958 - val_acc: 0.0781
# Epoch 3/5000
#  - 0s - loss: 3.7000 - acc: 0.1704 - val_loss: 2.7426 - val_acc: 0.2250
# Epoch 4/5000
#  - 0s - loss: 2.4997 - acc: 0.2635 - val_loss: 2.2036 - val_acc: 0.2719
# Epoch 5/5000
#  - 0s - loss: 2.0671 - acc: 0.2783 - val_loss: 1.9393 - val_acc: 0.2812
# Epoch 6/5000
#  - 0s - loss: 1.8566 - acc: 0.2901 - val_loss: 1.7821 - val_acc: 0.2844
# Epoch 7/5000
#  - 0s - loss: 1.7209 - acc: 0.3018 - val_loss: 1.6660 - val_acc: 0.2938
# Epoch 8/5000
#  - 0s - loss: 1.5988 - acc: 0.3120 - val_loss: 1.5481 - val_acc: 0.3000
# Epoch 9/5000
#  - 0s - loss: 1.4918 - acc: 0.3213 - val_loss: 1.4504 - val_acc: 0.3156
# Epoch 10/5000
#  - 0s - loss: 1.3951 - acc: 0.3284 - val_loss: 1.3718 - val_acc: 0.3250
# Epoch 11/5000
#  - 0s - loss: 1.3148 - acc: 0.3425 - val_loss: 1.2806 - val_acc: 0.3375
# Epoch 12/5000
#  - 0s - loss: 1.2282 - acc: 0.3440 - val_loss: 1.1982 - val_acc: 0.3406
# Epoch 13/5000
#  - 0s - loss: 1.1590 - acc: 0.3612 - val_loss: 1.1343 - val_acc: 0.3625
# Epoch 14/5000
#  - 0s - loss: 1.0855 - acc: 0.3878 - val_loss: 1.0663 - val_acc: 0.3812
# Epoch 15/5000
#  - 0s - loss: 1.0266 - acc: 0.3964 - val_loss: 1.0114 - val_acc: 0.3750
# Epoch 16/5000
#  - 0s - loss: 0.9763 - acc: 0.4097 - val_loss: 0.9499 - val_acc: 0.3969
# Epoch 17/5000
#  - 0s - loss: 0.9169 - acc: 0.4253 - val_loss: 0.9029 - val_acc: 0.3875
# Epoch 18/5000
#  - 0s - loss: 0.8707 - acc: 0.4308 - val_loss: 0.8526 - val_acc: 0.4062
# Epoch 19/5000
#  - 0s - loss: 0.8271 - acc: 0.4425 - val_loss: 0.8079 - val_acc: 0.4062
# Epoch 20/5000
#  - 0s - loss: 0.7817 - acc: 0.4488 - val_loss: 0.7664 - val_acc: 0.4031
# Epoch 21/5000
#  - 0s - loss: 0.7432 - acc: 0.4535 - val_loss: 0.7297 - val_acc: 0.4344
# Epoch 22/5000
#  - 0s - loss: 0.7074 - acc: 0.4605 - val_loss: 0.6963 - val_acc: 0.4156
# Epoch 23/5000
#  - 0s - loss: 0.6741 - acc: 0.4801 - val_loss: 0.6675 - val_acc: 0.4437
# Epoch 24/5000
#  - 0s - loss: 0.6418 - acc: 0.4848 - val_loss: 0.6350 - val_acc: 0.4437
# Epoch 25/5000
#  - 0s - loss: 0.6168 - acc: 0.4980 - val_loss: 0.6060 - val_acc: 0.4625
# Epoch 26/5000
#  - 0s - loss: 0.5909 - acc: 0.5043 - val_loss: 0.5824 - val_acc: 0.4688
# Epoch 27/5000
#  - 0s - loss: 0.5619 - acc: 0.5215 - val_loss: 0.5654 - val_acc: 0.4844
# Epoch 28/5000
#  - 0s - loss: 0.5453 - acc: 0.5309 - val_loss: 0.5393 - val_acc: 0.4938
# Epoch 29/5000
#  - 0s - loss: 0.5254 - acc: 0.5231 - val_loss: 0.5161 - val_acc: 0.5000
# Epoch 30/5000
#  - 0s - loss: 0.5053 - acc: 0.5434 - val_loss: 0.5041 - val_acc: 0.4969
# Epoch 31/5000
#  - 0s - loss: 0.4893 - acc: 0.5442 - val_loss: 0.4840 - val_acc: 0.5062
# Epoch 32/5000
#  - 0s - loss: 0.4718 - acc: 0.5536 - val_loss: 0.4824 - val_acc: 0.5156
# Epoch 33/5000
#  - 0s - loss: 0.4631 - acc: 0.5520 - val_loss: 0.4572 - val_acc: 0.5094
# Epoch 34/5000
#  - 0s - loss: 0.4428 - acc: 0.5723 - val_loss: 0.4415 - val_acc: 0.5344
# Epoch 35/5000
#  - 0s - loss: 0.4385 - acc: 0.5645 - val_loss: 0.4367 - val_acc: 0.5375
# Epoch 36/5000
#  - 0s - loss: 0.4252 - acc: 0.5887 - val_loss: 0.4190 - val_acc: 0.5250
# Epoch 37/5000
#  - 0s - loss: 0.4129 - acc: 0.5841 - val_loss: 0.4191 - val_acc: 0.5375
# Epoch 38/5000
#  - 0s - loss: 0.4043 - acc: 0.5825 - val_loss: 0.4044 - val_acc: 0.5281
# Epoch 39/5000
#  - 0s - loss: 0.4001 - acc: 0.6083 - val_loss: 0.4034 - val_acc: 0.5281
# Epoch 40/5000
#  - 0s - loss: 0.3870 - acc: 0.6067 - val_loss: 0.3933 - val_acc: 0.5563
# Epoch 41/5000
#  - 0s - loss: 0.3879 - acc: 0.6099 - val_loss: 0.3895 - val_acc: 0.5531
# Epoch 42/5000
#  - 0s - loss: 0.3832 - acc: 0.6083 - val_loss: 0.3864 - val_acc: 0.5281
# Epoch 43/5000
#  - 0s - loss: 0.3678 - acc: 0.6153 - val_loss: 0.3805 - val_acc: 0.5563
# Epoch 44/5000
#  - 0s - loss: 0.3620 - acc: 0.6294 - val_loss: 0.3832 - val_acc: 0.5437
# Epoch 45/5000
#  - 0s - loss: 0.3620 - acc: 0.6310 - val_loss: 0.3730 - val_acc: 0.5687
# Epoch 46/5000
#  - 0s - loss: 0.3551 - acc: 0.6271 - val_loss: 0.3726 - val_acc: 0.5531
# Epoch 47/5000
#  - 0s - loss: 0.3490 - acc: 0.6466 - val_loss: 0.3710 - val_acc: 0.5594
# Epoch 48/5000
#  - 0s - loss: 0.3469 - acc: 0.6278 - val_loss: 0.3692 - val_acc: 0.5687
# Epoch 49/5000
#  - 0s - loss: 0.3506 - acc: 0.6380 - val_loss: 0.3688 - val_acc: 0.5656
# Epoch 50/5000
#  - 0s - loss: 0.3405 - acc: 0.6443 - val_loss: 0.3658 - val_acc: 0.5594
# Epoch 51/5000
#  - 0s - loss: 0.3364 - acc: 0.6466 - val_loss: 0.3651 - val_acc: 0.5656
# Epoch 52/5000
#  - 0s - loss: 0.3342 - acc: 0.6482 - val_loss: 0.3663 - val_acc: 0.5719
# Epoch 53/5000
#  - 0s - loss: 0.3313 - acc: 0.6474 - val_loss: 0.3702 - val_acc: 0.5563
# Epoch 54/5000
#  - 0s - loss: 0.3285 - acc: 0.6568 - val_loss: 0.3623 - val_acc: 0.5687
# Epoch 55/5000
#  - 0s - loss: 0.3247 - acc: 0.6591 - val_loss: 0.3580 - val_acc: 0.5906
# Epoch 56/5000
#  - 0s - loss: 0.3299 - acc: 0.6568 - val_loss: 0.3584 - val_acc: 0.5875
# Epoch 57/5000
#  - 0s - loss: 0.3271 - acc: 0.6552 - val_loss: 0.3813 - val_acc: 0.5594
# Epoch 58/5000
#  - 0s - loss: 0.3309 - acc: 0.6638 - val_loss: 0.3753 - val_acc: 0.5750
# Epoch 59/5000
#  - 0s - loss: 0.3225 - acc: 0.6568 - val_loss: 0.3608 - val_acc: 0.5875
# Epoch 60/5000
#  - 0s - loss: 0.3156 - acc: 0.6583 - val_loss: 0.3527 - val_acc: 0.5875
# Epoch 61/5000
#  - 0s - loss: 0.3147 - acc: 0.6661 - val_loss: 0.3561 - val_acc: 0.5875
# Epoch 62/5000
#  - 0s - loss: 0.3112 - acc: 0.6669 - val_loss: 0.3551 - val_acc: 0.5938
# Epoch 63/5000
#  - 0s - loss: 0.3099 - acc: 0.6732 - val_loss: 0.3558 - val_acc: 0.6031
# Epoch 64/5000
#  - 0s - loss: 0.3114 - acc: 0.6654 - val_loss: 0.3561 - val_acc: 0.5875
# Epoch 65/5000
#  - 0s - loss: 0.3105 - acc: 0.6732 - val_loss: 0.3603 - val_acc: 0.6031
# Epoch 66/5000
#  - 0s - loss: 0.3063 - acc: 0.6701 - val_loss: 0.3525 - val_acc: 0.6031
# Epoch 67/5000
#  - 0s - loss: 0.3041 - acc: 0.6802 - val_loss: 0.3648 - val_acc: 0.6062
# Epoch 68/5000
#  - 0s - loss: 0.3055 - acc: 0.6716 - val_loss: 0.3540 - val_acc: 0.6031
# Epoch 69/5000
#  - 0s - loss: 0.2976 - acc: 0.6747 - val_loss: 0.3549 - val_acc: 0.6000
# Epoch 70/5000
#  - 0s - loss: 0.3009 - acc: 0.6802 - val_loss: 0.3608 - val_acc: 0.6062
# Epoch 71/5000
#  - 0s - loss: 0.2962 - acc: 0.6794 - val_loss: 0.3499 - val_acc: 0.5906
# Epoch 72/5000
#  - 0s - loss: 0.2935 - acc: 0.6818 - val_loss: 0.3535 - val_acc: 0.6031
# Epoch 73/5000
#  - 0s - loss: 0.2945 - acc: 0.6794 - val_loss: 0.3519 - val_acc: 0.5969
# Epoch 74/5000
#  - 0s - loss: 0.3002 - acc: 0.6677 - val_loss: 0.3524 - val_acc: 0.5938
# Epoch 75/5000
#  - 0s - loss: 0.2930 - acc: 0.6857 - val_loss: 0.3682 - val_acc: 0.5969
# Epoch 76/5000
#  - 0s - loss: 0.2865 - acc: 0.6810 - val_loss: 0.3569 - val_acc: 0.6219
# Epoch 77/5000
#  - 0s - loss: 0.2878 - acc: 0.6927 - val_loss: 0.3541 - val_acc: 0.5875
# Epoch 78/5000
#  - 0s - loss: 0.2853 - acc: 0.6904 - val_loss: 0.3644 - val_acc: 0.6094
# Epoch 79/5000
#  - 0s - loss: 0.2867 - acc: 0.6826 - val_loss: 0.3528 - val_acc: 0.6000
# Epoch 80/5000
#  - 0s - loss: 0.2828 - acc: 0.6919 - val_loss: 0.3567 - val_acc: 0.5813
# Epoch 81/5000
#  - 0s - loss: 0.2838 - acc: 0.6810 - val_loss: 0.3581 - val_acc: 0.5938
# Epoch 82/5000
#  - 0s - loss: 0.2861 - acc: 0.6787 - val_loss: 0.3606 - val_acc: 0.6188
# Epoch 83/5000
#  - 0s - loss: 0.2924 - acc: 0.6833 - val_loss: 0.3489 - val_acc: 0.6000
# Epoch 84/5000
#  - 0s - loss: 0.2845 - acc: 0.6919 - val_loss: 0.3609 - val_acc: 0.5906
# Epoch 85/5000
#  - 0s - loss: 0.2764 - acc: 0.6959 - val_loss: 0.3484 - val_acc: 0.6219
# Epoch 86/5000
#  - 0s - loss: 0.2749 - acc: 0.6990 - val_loss: 0.3579 - val_acc: 0.6219
# Epoch 87/5000
#  - 0s - loss: 0.2785 - acc: 0.6927 - val_loss: 0.3551 - val_acc: 0.6156
# Epoch 88/5000
#  - 0s - loss: 0.2737 - acc: 0.7084 - val_loss: 0.3553 - val_acc: 0.5969
# Epoch 89/5000
#  - 0s - loss: 0.2773 - acc: 0.6919 - val_loss: 0.3611 - val_acc: 0.6031
# Epoch 90/5000
#  - 0s - loss: 0.2717 - acc: 0.6857 - val_loss: 0.3528 - val_acc: 0.6031
# Epoch 91/5000
#  - 0s - loss: 0.2764 - acc: 0.6998 - val_loss: 0.3512 - val_acc: 0.6062
# Epoch 92/5000
#  - 0s - loss: 0.2690 - acc: 0.6998 - val_loss: 0.3494 - val_acc: 0.6125
# Epoch 93/5000
#  - 0s - loss: 0.2694 - acc: 0.7029 - val_loss: 0.3519 - val_acc: 0.6156
# Epoch 94/5000
#  - 0s - loss: 0.2660 - acc: 0.7084 - val_loss: 0.3573 - val_acc: 0.6125
# Epoch 95/5000
#  - 0s - loss: 0.2677 - acc: 0.7013 - val_loss: 0.3476 - val_acc: 0.6188
# Epoch 96/5000
#  - 0s - loss: 0.2688 - acc: 0.7045 - val_loss: 0.3581 - val_acc: 0.5969
# Epoch 00096: early stopping

# %%
best_model = model
best_model.load_weights('checkpoints/multi_layer_best_model.h5')
best_model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# Evaluate on test set
score = best_model.evaluate(X_test.values, y_test, verbose=0)
print('Test accuracy: %.2f%%' % (score[1]*100))

# Test accuracy: 65.62% 
# Benchmark accuracy on dataset 62.4%
